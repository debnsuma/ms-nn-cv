# %% [markdown]
# #### **In This Lecture, We Will Cover:**
# - A brief introduction to Computer Vision field.
# - Why Vanilla NN is **NOT** suited for Image Data? Explained with a real-world example!
# - Taking motivations for a new architecture from **Human Visual Cortex System**.
# - Defining the new architecture, aka **CNNs** and its components!

# %% [markdown]
# ####Q. **What is Computer Vision (CV)?**
#
# Simply put, Computer Vision is a field of AI that enables machine to derive **Meaningful Information from Images**, Some Examples:
#
# - Detect all the **Objects** in the Image -
# ><img src='https://drive.google.com/uc?id=1kPFldAGjtfyLm7msBNf9mf5cWsMXLJp5' height=250>
#
#
# - Extract **Text** from the Image -
# ><img src='https://drive.google.com/uc?id=1c9nP2lWR5ig_IMda1vhyIJcmegxANOKp' width=250>
#
#
# - Write one-line describing the Image(known as **Image Captioning**) -
# ><img src='https://drive.google.com/uc?id=1uH7SKPJco1O0tFU7Rs6uZOuJvKVG8EEE' height=250>
#
#
# These problems might be easy for humans as we are trained with 500,000,000 years of image data, but What about Computers?
#
# Before even answering this question, let's investigate - <br>
# ###**What a Computer actually sees?**<br>
# - A **Digital Image** is a matrix of size (H,W,C), comprising of numbers (also known as pixel values) typically ranging from 0-255. Here H,W,C denote Height, Width and No. of Channels in a image.
# - For a Grayscale image, # channels is 1, while for Colored Image its 3.
#
# ><img src='https://drive.google.com/uc?id=1v9Q1ivDG7niiOB00qnKDhzvs_iJKHFY5' height=250>
#
# ><img src='https://drive.google.com/uc?id=1q8RHb2Lt25yvzpojTl4xu8OqroazfxO2' height=250>
#
# ####Q. **Is CV Easy?**
# We used Google's Vision API to find out what it detects in the above image.
# And the result was ...**...BAD**
# ><img src='https://drive.google.com/uc?id=1Aoc_MLvUNxVGrddvCvKyzeHxfPfGZ6FU' height=450>
#
# ####Q. **CV is Hard, How?**
# - Occlusion
# ><img src='https://drive.google.com/uc?id=1BEPnFwfEHbyS9B0mGuwH3PrXoSD3hD3p' height=350>
# - Illumination variability
# ><img src='https://drive.google.com/uc?id=1lCwC1MQ3J8oLEI8wVUUASvEDezyvzxny' height=350>
# - Pose Variability
# ><img src='https://drive.google.com/uc?id=1EomrGXii9kUWuFBAdvj97VnGY5Gs57JZ' height=350>
#
#
# **Scope of CV is Enormous!**
# - Computer vision is used in industry leading products like self-driving cars, automated robots, drones, medical image analysis, etc.
# - Apart from this, CV is also used in conjunction with other fields of AI like Speech and NLP.
# - For example, in the case of Speech Recognition, we first convert audio chunks to 2D matrices (called mel spectrogram) and treat it like images. In NLP, we use CV techniques for Image Captioning and very recently Image Synthesis from prompts.
#
# >*Note that the above image of dog is artificially generated using [Stable Diffusion](https://huggingface.co/spaces/stabilityai/stable-diffusion) model, with the following prompt: `A dog made of origami. Highly detailed. Photograph. 4k. Colorful`*

# %% [markdown]
# ####Q. **Why Deep Neural Network for Images?**
#
# In order to understand why DNN works, we need to account for how visual cortex functions!
#
# Our Visual Cortex system is arranged in layers and as information passes from the eyes to deeper parts of the brain, higher and higher order representations are formed. Since a DNN also works in a similar way, using it for analyzing Images makes perfect sense.
#
#
# <img src='https://drive.google.com/uc?id=1IkIqSSDHlSLeVDHdu1n-ZsHbiqMs5nAe' height=550>
#
# ####**But what about the architecture of DNN, will Vanilla NN or MLP be a suitable fit?**
#
# ### We will answer this question in Part 1 of the module!

# %% [markdown]
# # PART 1: Hammer and Screw
#
# <img src='https://drive.google.com/uc?id=1O94kFYu6pvDMeNuWKQ7HKgwNlFgllNAV' height=280 width=400>
#
#
# In the Previous lectures we learnt about ANNs and where to use them.
#
# Now let's experiment what happens if we try to fit a Vanilla Neural Network (Hammer) to a very different kind of data, aka Images (Screw) and why this hammering of screw doesn't make sense!
#
# ## You are working as a Data Scientist at Amazon
# - Amazon wants to develop an automated system to categorize a clothing product into its master category
#     - Link of website to show demo :(https://www.amazon.in/b/?_encoding=UTF8&node=7459780031&ref_=sv_top_ap_mega_1)
# - You are given the job to classify clothes into 10 different classes
# - Since it's a multi-class classification problem on a labelled dataset and you have just studied about ANN, you feel encouraged to apply it to this scenario.
# - You try to implement a ANN but somehow, it gives very poor results
# - So why didn't the ANN work..? and what else would ?
#
# Let's find out -

# %% [markdown]
# # Part 1: (Hammering the Screw)
#
#   Scenario:  **Classify the fashion image into one of the 10 categories**
#   Inventory: Vanilla NN (hammer) and CNN (new tool)
#
# <center><img src='https://drive.google.com/uc?id=1xL9UKISIdQPOSh3B_Z_ac3-8MzoW3jp7' width=500 height=300>
# </center>

# %% [markdown]
# ## 0. Setup
#
# As always, we will start by downloading resources, installing packages and importing them to the environment!
# - 0.1 Download Resources
# - 0.2 Import Libraries

# %% [markdown]
# ### 0.1 Download Data
#
# We are going to use a collection of real-world clothing images dataset, opensourced [here](https://github.com/alexeygrigorev/clothing-dataset-small).
#
# You can read more about the dataset in this [blog post](https://medium.com/data-science-insider/clothing-dataset-5b72cd7c3f1f).

# %%
# !gdown https://drive.google.com/uc?id=1XdXz0TKo_KCDRHOMvzV-YtcTx7NPG-jC
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1XdXz0TKo_KCDRHOMvzV-YtcTx7NPG-jC
# To: /content/clothing-dataset-small.zip
# 100% 106M/106M [00:03<00:00, 30.2MB/s]

# %%
# !unzip /content/clothing-dataset-small.zip
# Out:
# Archive:  /content/clothing-dataset-small.zip
#    creating: clothing-dataset-small/
#   inflating: clothing-dataset-small/.DS_Store
#    creating: clothing-dataset-small/test/
#    creating: clothing-dataset-small/test/skirt/
#   inflating: clothing-dataset-small/test/skirt/f4b934fc-e326-4f72-b535-53288b8b82d3.jpg
#   inflating: clothing-dataset-small/test/skirt/491982c3-3e90-431e-99e6-b14ecea36384.jpg
#   inflating: clothing-dataset-small/test/skirt/24963db3-649c-4f04-8da3-0375ede8e0a6.jpg
#   inflating: clothing-dataset-small/test/skirt/32b99302-cec7-4dec-adfa-3d4029674209.jpg
#   inflating: clothing-dataset-small/test/skirt/0558b2c5-be00-49de-b27f-8c88114ac36f.jpg
#   inflating: clothing-dataset-small/test/skirt/95e66e02-b4ed-4fe9-b538-db6bac4fb7df.jpg
#   inflating: clothing-dataset-small/test/skirt/2001dec1-1e0a-4c11-9d15-120b019b3dea.jpg
#   inflating: clothing-dataset-small/test/skirt/b0e05193-cc92-4935-88d7-e71a1b19dd4b.jpg
#   inflating: clothing-dataset-small/test/skirt/309829b2-6d1a-4173-8d46-2dbdd10aad90.jpg
#   inflating: clothing-dataset-small/test/skirt/dab7f764-1232-4a8a-952c-01ee1a2aa16b.jpg
#   inflating: clothing-dataset-small/test/skirt/5144499e-7848-4441-8873-7daab5386eec.jpg
#   inflating: clothing-dataset-small/test/skirt/84b4da94-65c0-471e-a7ad-2ba6360f45bb.jpg
#    creating: clothing-dataset-small/test/longsleeve/
#   inflating: clothing-dataset-small/test/longsleeve/fc34b591-392c-4ed8-8e26-71a386e0d9b3.jpg
#   inflating: clothing-dataset-small/test/longsleeve/beea9d8c-3723-45df-8e85-1bdad1adb324.jpg
#   inflating: clothing-dataset-small/test/longsleeve/febe9c7c-1551-45ae-8324-b8a5bb9fc8a3.jpg
#   inflating: clothing-dataset-small/test/longsleeve/28fc3fad-5363-4c70-9c5d-ee739d2e21a8.jpg
#   inflating: clothing-dataset-small/test/longsleeve/aa8c2c36-a267-4a3b-9ec4-9a0aac37683c.jpg
#   inflating: clothing-dataset-small/test/longsleeve/8d1cfb8d-6e6c-4dbe-999a-0272d986f901.jpg
#   inflating: clothing-dataset-small/test/longsleeve/c5c2b0ac-d798-46a9-8f18-c5acb1fd5e08.jpg
#   inflating: clothing-dataset-small/test/longsleeve/e9274307-85c1-480b-842c-4fdc193285c1.jpg
#   inflating: clothing-dataset-small/test/longsleeve/0f4d9494-612a-48f8-be05-e47f4fc54d54.jpg
#   inflating: clothing-dataset-small/test/longsleeve/f8ed83e3-5d6f-4f78-8838-2d6b8836d98b.jpg
#   inflating: clothing-dataset-small/test/longsleeve/87665c15-a141-4ba4-9804-5e41fddefb71.jpg
#   inflating: clothing-dataset-small/test/longsleeve/6017e83a-f717-48d6-8f68-f4b614c215a8.jpg
#   inflating: clothing-dataset-small/test/longsleeve/acf7a391-8450-453d-898b-2a4a9d2886f6.jpg
#   inflating: clothing-dataset-small/test/longsleeve/6c677bce-2564-46d4-8ca0-c372250aeaf4.jpg
#   inflating: clothing-dataset-small/test/longsleeve/d5bd0641-fa5e-4757-ae93-000a0439fd38.jpg
#   inflating: clothing-dataset-small/test/longsleeve/4cd7315a-395b-4958-b8e5-e38f09b3c6b2.jpg
#   inflating: clothing-dataset-small/test/longsleeve/3982179b-1523-4cea-868d-4dd3e71779b0.jpg
#   inflating: clothing-dataset-small/test/longsleeve/973b5b65-72ef-41b4-8290-0ee84dd44bce.jpg
#   inflating: clothing-dataset-small/test/longsleeve/8af49c5b-d565-46fb-aeb7-2a49a73d17b4.jpg
#   inflating: clothing-dataset-small/test/longsleeve/64b0151b-6138-470c-b699-8fb6db3898f2.jpg
#   inflating: clothing-dataset-small/test/longsleeve/49431f72-6423-4fd9-953b-d55bf8f4830a.jpg
#   inflating: clothing-dataset-small/test/longsleeve/368ef683-0c8c-4ba1-a73b-d784b851165a.jpg
#   inflating: clothing-dataset-small/test/longsleeve/341e1658-0cba-4ac2-aa39-e5b174e318fd.jpg
#   inflating: clothing-dataset-small/test/longsleeve/d7bef10a-3d8d-4aa5-98d3-5cc639ee723f.jpg
#   inflating: clothing-dataset-small/test/longsleeve/3c4d6cf5-113b-4a26-8e60-e8ab594eaa0e.jpg
#   inflating: clothing-dataset-small/test/longsleeve/cbabc6f4-e6a8-4d02-9027-b746fa2749e4.jpg
#   inflating: clothing-dataset-small/test/longsleeve/92a51811-7451-4d89-84aa-56ff44e5c4f4.jpg
#   inflating: clothing-dataset-small/test/longsleeve/c44195bb-66c5-44b1-806a-aebd703f0298.jpg
#   inflating: clothing-dataset-small/test/longsleeve/ea1c48df-db46-4ceb-b168-3cd184975225.jpg
#   inflating: clothing-dataset-small/test/longsleeve/df002747-cc0a-4340-96ca-ead83cad11c0.jpg
#   inflating: clothing-dataset-small/test/longsleeve/54a7aa48-feef-4689-93ba-cc475f93c4e7.jpg
#   inflating: clothing-dataset-small/test/longsleeve/ddc3da65-2ba7-4012-adf4-0b6e636fad6b.jpg
#   inflating: clothing-dataset-small/test/longsleeve/1f2c3551-4c76-433e-8c9f-8093b94f02bf.jpg
#   inflating: clothing-dataset-small/test/longsleeve/c17a15e5-7074-4e0c-83d4-430ac8a9dbf7.jpg
#   inflating: clothing-dataset-small/test/longsleeve/63fd7e77-fa32-44a2-964b-8ab764ca9efa.jpg
#   inflating: clothing-dataset-small/test/longsleeve/d898c146-ef98-42ef-ad34-062d0a089673.jpg
#   inflating: clothing-dataset-small/test/longsleeve/3132e018-4cc7-4767-a2b6-0ac61321809a.jpg
#   inflating: clothing-dataset-small/test/longsleeve/03a33083-e7bf-414d-bd35-c56273ae779c.jpg
#   inflating: clothing-dataset-small/test/longsleeve/d2b3f788-d449-450a-ad4f-56c322bcb681.jpg
#   inflating: clothing-dataset-small/test/longsleeve/e5a96bcb-997e-48e8-bb48-fa31513a2df0.jpg
#   inflating: clothing-dataset-small/test/longsleeve/91c4b8c1-fd2f-47ea-b496-8191d36a2e3b.jpg
#   inflating: clothing-dataset-small/test/longsleeve/986a1c8f-f5b8-45a6-afc4-701a0255ac20.jpg
#   inflating: clothing-dataset-small/test/longsleeve/9d662e99-37a1-4e5a-a068-d38556d6c436.jpg
#   inflating: clothing-dataset-small/test/longsleeve/675319cc-b2f9-4b92-a126-472d4bcefdee.jpg
#   inflating: clothing-dataset-small/test/longsleeve/a9aa8ca4-d288-4bb0-a5da-c2af541743b0.jpg
#   inflating: clothing-dataset-small/test/longsleeve/841cdda3-162f-4ae3-a86b-3596f414801f.jpg
#   inflating: clothing-dataset-small/test/longsleeve/24c1d77c-5ce2-4b5c-be2c-1aeccae3efe2.jpg
#   inflating: clothing-dataset-small/test/longsleeve/9de134ba-d7c3-4f7c-8f44-217f213adca6.jpg
#   inflating: clothing-dataset-small/test/longsleeve/a16d135e-9907-471b-9e5c-ac46a006764e.jpg
#   inflating: clothing-dataset-small/test/longsleeve/1b93822d-09f4-41e6-b31b-964cc104ba71.jpg
#   inflating: clothing-dataset-small/test/longsleeve/2e4bde7e-e9b9-4097-a64b-0ff017e28e3c.jpg
#   inflating: clothing-dataset-small/test/longsleeve/58d54528-9eb3-4188-beca-892932f360a7.jpg
#   inflating: clothing-dataset-small/test/longsleeve/f595e51b-e236-48bd-94c2-814391176b62.jpg
#   inflating: clothing-dataset-small/test/longsleeve/2c050ddf-2681-4a03-9d0f-3b96b9cd5fe5.jpg
#   inflating: clothing-dataset-small/test/longsleeve/f127b3f0-9392-4eb6-b293-15b75993f7d7.jpg
#   inflating: clothing-dataset-small/test/longsleeve/6b7e076a-5c7b-46c4-8847-3be2efcc1cb4.jpg
#   inflating: clothing-dataset-small/test/longsleeve/cb84ea96-fd31-4c51-b01d-b66e07c28e36.jpg
#   inflating: clothing-dataset-small/test/longsleeve/4e0f02de-645d-4615-a13b-749d8027c85b.jpg
#   inflating: clothing-dataset-small/test/longsleeve/cd6b14e7-970b-4472-9241-af346237ba75.jpg
#   inflating: clothing-dataset-small/test/longsleeve/70fd429b-73ec-4b4a-9173-2b6efbe7d6ee.jpg
#   inflating: clothing-dataset-small/test/longsleeve/85c26e4d-f390-4405-8686-4ce202d43b14.jpg
#   inflating: clothing-dataset-small/test/longsleeve/bd37c451-2e49-4688-bc91-84edac27bb7c.jpg
#   inflating: clothing-dataset-small/test/longsleeve/5280b156-7db0-47f2-918c-6b0b6592955b.jpg
#   inflating: clothing-dataset-small/test/longsleeve/0df1efc7-34ba-4e11-b027-21ec8fa5a35e.jpg
#   inflating: clothing-dataset-small/test/longsleeve/c2f88dd3-f4d5-4c5f-b715-f6191f1233f3.jpg
#   inflating: clothing-dataset-small/test/longsleeve/d4eea203-72d6-4f7a-a212-ed214c7567f0.jpg
#   inflating: clothing-dataset-small/test/longsleeve/bbb7cf34-ca92-4471-a1e0-df0cea61e9dd.jpg
#   inflating: clothing-dataset-small/test/longsleeve/6e4581ed-c575-4d31-8aa4-9814bd6672a3.jpg
#   inflating: clothing-dataset-small/test/longsleeve/c9c6c0f7-b3b4-4f72-9ba3-f65f3d024d14.jpg
#   inflating: clothing-dataset-small/test/longsleeve/b4094c8d-68c9-4854-99c9-ee88ed37d6e5.jpg
#   inflating: clothing-dataset-small/test/longsleeve/11f2ff4e-6b43-4071-b5b1-2036ec0fe8fe.jpg
#   inflating: clothing-dataset-small/test/longsleeve/1789bd08-1ac8-46d6-bf28-0919e083ef56.jpg
#    creating: clothing-dataset-small/test/dress/
#   inflating: clothing-dataset-small/test/dress/facbf570-2a46-43cd-b58b-ea03df3e7919.jpg
#   inflating: clothing-dataset-small/test/dress/35f157d0-53e4-4496-b087-da4ad63edd47.jpg
#   inflating: clothing-dataset-small/test/dress/d9afe9d4-8bb3-4449-9e4b-85fcf030ba1b.jpg
#   inflating: clothing-dataset-small/test/dress/5a2b4bbf-d9fe-45a2-aa0d-295a86804cb6.jpg
#   inflating: clothing-dataset-small/test/dress/28b09463-6bbb-491d-9ffc-f36df5c6b211.jpg
#   inflating: clothing-dataset-small/test/dress/8c6b26f9-e3d4-483b-99bd-db4f6beff442.jpg
#   inflating: clothing-dataset-small/test/dress/50d248fe-de40-4bb6-9bff-3e8babecba31.jpg
#   inflating: clothing-dataset-small/test/dress/bac70656-a50a-4a13-8c3f-63e3a0a28338.jpg
#   inflating: clothing-dataset-small/test/dress/ee7b4f87-ab2e-4387-9c7e-76f7da060f1e.jpg
#   inflating: clothing-dataset-small/test/dress/06a00c0f-5f9a-410d-a7da-3881a9df3a71.jpg
#   inflating: clothing-dataset-small/test/dress/c6bc821e-631a-4221-9d92-7c7685edebd0.jpg
#   inflating: clothing-dataset-small/test/dress/cbf45350-1a65-4cec-abad-0f64a4a459eb.jpg
#   inflating: clothing-dataset-small/test/dress/4ceed2f1-8e20-4439-9c27-cceb8d2257a4.jpg
#   inflating: clothing-dataset-small/test/dress/7f60d367-31dd-49ad-80ae-b5223364f386.jpg
#   inflating: clothing-dataset-small/test/dress/3f844e1e-4a00-4b64-8c1d-3b847191bf11.jpg
#    creating: clothing-dataset-small/test/pants/
#   inflating: clothing-dataset-small/test/pants/9f0338d5-37b9-4837-964d-d68fa08cec3b.jpg
#   inflating: clothing-dataset-small/test/pants/fefa13bc-8c4a-4613-ae84-56d379d46984.jpg
#   inflating: clothing-dataset-small/test/pants/e3229e00-607a-4172-86b0-7205ac0c15fa.jpg
#   inflating: clothing-dataset-small/test/pants/bb336291-dc5d-442d-91f8-fcdf6cd258a4.jpg
#   inflating: clothing-dataset-small/test/pants/eaa3318c-3c73-419e-a952-7c9d0ac845d9.jpg
#   inflating: clothing-dataset-small/test/pants/4aabd82c-82e1-4181-a84d-d0c6e550d26d.jpg
#   inflating: clothing-dataset-small/test/pants/a3e47bc3-ba2d-480d-a2bd-1c9d2c96abd8.jpg
#   inflating: clothing-dataset-small/test/pants/93ca234f-1229-4ee3-a05d-127959b2c0ba.jpg
#   inflating: clothing-dataset-small/test/pants/53a11bca-e1d7-45a3-8ab0-a17cab3062d1.jpg
#   inflating: clothing-dataset-small/test/pants/9b94e20c-7ed2-4e8d-a9c2-884e3b685770.jpg
#   inflating: clothing-dataset-small/test/pants/442b93ee-a08b-4bba-8a89-35d8453cf2f5.jpg
#   inflating: clothing-dataset-small/test/pants/c8d21106-bbdb-4e8d-83e4-bf3d14e54c16.jpg
#   inflating: clothing-dataset-small/test/pants/6c02ba6f-ca72-4b8c-b7c4-a2fb0c14bfb5.jpg
#   inflating: clothing-dataset-small/test/pants/40584096-ab8a-4a68-8d10-f6d94aa6f4b3.jpg
#   inflating: clothing-dataset-small/test/pants/6733e81a-d9a2-4f7c-869e-3420ab467112.jpg
#   inflating: clothing-dataset-small/test/pants/f9aaa937-0247-4cb6-be62-d44248ef6cbc.jpg
#   inflating: clothing-dataset-small/test/pants/361cbb64-95f4-4be3-a01c-3aba98fa509f.jpg
#   inflating: clothing-dataset-small/test/pants/1b5f2882-e33e-4efc-b469-bcf87b9f53ed.jpg
#   inflating: clothing-dataset-small/test/pants/122f0c94-4f37-4010-8c43-06d79bdf4433.jpg
#   inflating: clothing-dataset-small/test/pants/05814dc4-0520-47e6-91e0-402a971ba40a.jpg
#   inflating: clothing-dataset-small/test/pants/52f73c9e-93da-47ae-bf67-f0e7b8216fe1.jpg
#   inflating: clothing-dataset-small/test/pants/c362d096-021d-4948-81ef-c2a971dc0998.jpg
#   inflating: clothing-dataset-small/test/pants/c313f8f9-82ab-4b99-a30a-c9c1f9d0c33d.jpg
#   inflating: clothing-dataset-small/test/pants/7447eb77-7509-4d30-ab41-0087749e05bd.jpg
#   inflating: clothing-dataset-small/test/pants/f622318b-beb2-4f69-a99d-d8fbce6c2600.jpg
#   inflating: clothing-dataset-small/test/pants/663c933e-ff70-4221-b3f1-9a4f63f828e8.jpg
#   inflating: clothing-dataset-small/test/pants/0dfec862-c49f-430b-a6ef-c7ceb187225e.jpg
#   inflating: clothing-dataset-small/test/pants/2884d941-ccc9-4eac-b7d7-b9996126a9c8.jpg
#   inflating: clothing-dataset-small/test/pants/8e6e5d4e-308c-4c92-9c35-cb87618ec370.jpg
#   inflating: clothing-dataset-small/test/pants/15a1e02b-ad2a-4b9f-9d44-0e4d260594a8.jpg
#   inflating: clothing-dataset-small/test/pants/60a480db-8685-4988-8ee2-31f2b83d07ff.jpg
#   inflating: clothing-dataset-small/test/pants/84d794c2-532b-425e-aea0-6454d02ee5c1.jpg
#   inflating: clothing-dataset-small/test/pants/6a680b10-7c3b-40c6-8943-d068d0be7ab4.jpg
#   inflating: clothing-dataset-small/test/pants/acb3fd5d-6c6f-4539-89e3-f67220ad6c83.jpg
#   inflating: clothing-dataset-small/test/pants/046d0a65-f5a6-47f6-afaf-e692bfcfcb00.jpg
#   inflating: clothing-dataset-small/test/pants/7d3a88e9-2fb3-4044-bdb2-5bbdf66d8a1b.jpg
#   inflating: clothing-dataset-small/test/pants/da1d3568-0e88-4dea-88f4-ab910b0a59e1.jpg
#   inflating: clothing-dataset-small/test/pants/ee6e5a32-db5d-4a02-b46b-9804738ade9e.jpg
#   inflating: clothing-dataset-small/test/pants/01033304-f9a4-48c4-af65-677512880fae.jpg
#   inflating: clothing-dataset-small/test/pants/241836fb-0adb-402a-8417-9825051f8912.jpg
#   inflating: clothing-dataset-small/test/pants/86d27363-bc32-4e4d-9f4f-7581866e9b8a.jpg
#   inflating: clothing-dataset-small/test/pants/25e7d73a-cd9a-4c2b-ab36-594ee2827745.jpg
#    creating: clothing-dataset-small/test/t-shirt/
#   inflating: clothing-dataset-small/test/t-shirt/ce8d7054-ee06-4412-b5df-a610943e3e50.jpg
#   inflating: clothing-dataset-small/test/t-shirt/2cc6e505-1a89-42e0-8177-017118117027.jpg
#   inflating: clothing-dataset-small/test/t-shirt/a526cbda-d3c9-467a-8090-98ce0b28dcdd.jpg
#   inflating: clothing-dataset-small/test/t-shirt/56c195bd-7685-4666-9a45-05a755758335.jpg
#   inflating: clothing-dataset-small/test/t-shirt/e62adabe-36ff-4af7-b8b3-82ad15a33458.jpg
#   inflating: clothing-dataset-small/test/t-shirt/ac78b6e0-a539-4fc0-8a3b-6afcbf08b799.jpg
#   inflating: clothing-dataset-small/test/t-shirt/687dd295-0b3d-4fce-aefe-1e72aaf0e687.jpg
#   inflating: clothing-dataset-small/test/t-shirt/9db6122f-e222-48f3-8147-fd1e56e92a6a.jpg
#   inflating: clothing-dataset-small/test/t-shirt/58aaf4e2-5a92-4c59-9321-6b37e65dcc46.jpg
#   inflating: clothing-dataset-small/test/t-shirt/b7d4f382-14f4-40f2-8fce-f32b08f0c553.jpg
#   inflating: clothing-dataset-small/test/t-shirt/db398f2d-24a3-4af1-9816-c269709a48b3.jpg
#   inflating: clothing-dataset-small/test/t-shirt/f16b720a-23cf-46df-833e-af8467b4a766.jpg
#   inflating: clothing-dataset-small/test/t-shirt/a0cfdcc7-74f1-4189-b2e6-82ceb9c41085.jpg
#   inflating: clothing-dataset-small/test/t-shirt/7de33c36-7554-474d-84ce-7f7281a5278f.jpg
#   inflating: clothing-dataset-small/test/t-shirt/3ce2017c-8365-4236-a7a7-f3d03639c583.jpg
#   inflating: clothing-dataset-small/test/t-shirt/fd290621-7999-4ea1-aa17-ae6eee86558e.jpg
#   inflating: clothing-dataset-small/test/t-shirt/1f2ba16d-c9a7-4ab9-bbb1-d13114078685.jpg
#   inflating: clothing-dataset-small/test/t-shirt/521ae02b-d891-4acd-8656-514a66312828.jpg
#   inflating: clothing-dataset-small/test/t-shirt/4f242ce1-8493-408d-ae63-2422a7cdc21e.jpg
#   inflating: clothing-dataset-small/test/t-shirt/941adb4c-bf6f-4d99-b355-6b0df31fa16a.jpg
#   inflating: clothing-dataset-small/test/t-shirt/ca9209cb-00b5-489e-80c4-61c16ac04479.jpg
#   inflating: clothing-dataset-small/test/t-shirt/e13f0056-a908-4593-aa86-de593774c049.jpg
#   inflating: clothing-dataset-small/test/t-shirt/01fd527c-da05-4141-861c-3aaec8070601.jpg
#   inflating: clothing-dataset-small/test/t-shirt/29cffc8e-5e72-4b73-bbc0-20b9f1251bc2.jpg
#   inflating: clothing-dataset-small/test/t-shirt/7fe4daa4-2802-42b4-8dee-68c114105a7a.jpg
#   inflating: clothing-dataset-small/test/t-shirt/4a9835a4-f5f4-43aa-882a-0fe494e61137.jpg
#   inflating: clothing-dataset-small/test/t-shirt/e917e5f9-2394-4e18-a69d-bacaa9a6a3a1.jpg
#   inflating: clothing-dataset-small/test/t-shirt/4503dd0b-bd55-42bc-a533-4b7462c346be.jpg
#   inflating: clothing-dataset-small/test/t-shirt/259f2358-fb94-4e7e-bd05-864e28071c17.jpg
#   inflating: clothing-dataset-small/test/t-shirt/f98d3a50-c57a-46ec-b313-437b97dc7507.jpg
#   inflating: clothing-dataset-small/test/t-shirt/648f665e-14d5-4c59-8866-e75f88ae3c8c.jpg
#   inflating: clothing-dataset-small/test/t-shirt/39262aa5-eb53-4d26-879a-c0bdb560d7fe.jpg
#   inflating: clothing-dataset-small/test/t-shirt/ec79d430-8b51-42ce-871f-050883252775.jpg
#   inflating: clothing-dataset-small/test/t-shirt/c5d81eb6-1823-4d83-a6bf-48f9463e201e.jpg
#   inflating: clothing-dataset-small/test/t-shirt/d9876909-14f3-4b0a-8523-226e0c7e14db.jpg
#   inflating: clothing-dataset-small/test/t-shirt/7636684a-b9f1-44f8-8cda-0efbcba53ba7.jpg
#   inflating: clothing-dataset-small/test/t-shirt/ffa2be27-0798-488d-b9de-254de2226667.jpg
#   inflating: clothing-dataset-small/test/t-shirt/bc5e96d7-419d-49c6-abf6-cd6cae89296d.jpg
#   inflating: clothing-dataset-small/test/t-shirt/0c024616-1289-4747-91da-71a4aedd4ced.jpg
#   inflating: clothing-dataset-small/test/t-shirt/a8886e1f-5940-495a-a684-7355545fece8.jpg
#   inflating: clothing-dataset-small/test/t-shirt/0af4203f-8998-4719-92fe-65c14a6b6093.jpg
#   inflating: clothing-dataset-small/test/t-shirt/d0a93d9e-6dc3-4f5a-9b3d-4f741c537d18.jpg
#   inflating: clothing-dataset-small/test/t-shirt/ddbfd678-7089-4d80-9aea-76a85d3fdd9f.jpg
#   inflating: clothing-dataset-small/test/t-shirt/18b6e35b-e8a0-4d9b-b3f5-bb96021ed9fb.jpg
#   inflating: clothing-dataset-small/test/t-shirt/80f0c986-0a06-419c-97a5-c56d6bd3d840.jpg
#   inflating: clothing-dataset-small/test/t-shirt/172950bd-f639-4ce5-bc55-d17cea7b9705.jpg
#   inflating: clothing-dataset-small/test/t-shirt/87f0802f-4ec0-4e20-a6cc-db90a85daffd.jpg
#   inflating: clothing-dataset-small/test/t-shirt/b18a958b-7b4b-4368-a7b3-3357d7fa6c3b.jpg
#   inflating: clothing-dataset-small/test/t-shirt/8f781680-32ee-441d-b175-72383e485817.jpg
#   inflating: clothing-dataset-small/test/t-shirt/05d01bf9-6ff5-4c5e-b946-b4ca004a125b.jpg
#   inflating: clothing-dataset-small/test/t-shirt/eae22f2a-bd28-450a-b38f-a94b03e28785.jpg
#   inflating: clothing-dataset-small/test/t-shirt/3e88a1d2-832b-49bd-b471-53f03b1b66ff.jpg
#    creating: clothing-dataset-small/test/shorts/
#   inflating: clothing-dataset-small/test/shorts/9935412e-9bfe-49be-b291-574c235e32fb.jpg
#   inflating: clothing-dataset-small/test/shorts/d2de6083-5de4-4c29-9ff9-660759f40434.jpg
#   inflating: clothing-dataset-small/test/shorts/3bf0d767-b78d-44e4-8b25-740aeb870b06.jpg
#   inflating: clothing-dataset-small/test/shorts/879ed4b1-2e9c-4770-9b6a-ce083cdab913.jpg
#   inflating: clothing-dataset-small/test/shorts/5176fdc6-3c9b-4291-854e-487861248b4b.jpg
#   inflating: clothing-dataset-small/test/shorts/39a1562b-9f9f-4e70-b593-79cdd63ac707.jpg
#   inflating: clothing-dataset-small/test/shorts/1e302085-eeb2-46ff-a4f6-e9bb5cfa44b1.jpg
#   inflating: clothing-dataset-small/test/shorts/dfd4079d-967b-4b3e-8574-fbac11b58103.jpg
#   inflating: clothing-dataset-small/test/shorts/9ebafad8-4684-4283-8c17-5a9a0114a707.jpg
#   inflating: clothing-dataset-small/test/shorts/cbae96c4-ee32-4c10-a69e-d723e0a54480.jpg
#   inflating: clothing-dataset-small/test/shorts/6aa97899-d731-4d8b-9a96-0db401c28500.jpg
#   inflating: clothing-dataset-small/test/shorts/81102c20-d268-4034-9058-a2580b4c63c9.jpg
#   inflating: clothing-dataset-small/test/shorts/71238a2e-59be-4d4b-ac0e-9739d13fd41d.jpg
#   inflating: clothing-dataset-small/test/shorts/40b704ca-eaa5-4cf9-a98d-0e3e2b0294ac.jpg
#   inflating: clothing-dataset-small/test/shorts/fe85d21f-4ccf-41fd-b54d-5bc6ee0b0eec.jpg
#   inflating: clothing-dataset-small/test/shorts/18260a42-3e2a-4bc6-b530-69135bf90434.jpg
#   inflating: clothing-dataset-small/test/shorts/15ce3cc0-4803-428f-8a4b-fb76cf30f297.jpg
#   inflating: clothing-dataset-small/test/shorts/6282a88b-92ba-47a6-bb60-67eb1aff9f14.jpg
#   inflating: clothing-dataset-small/test/shorts/927f499a-882b-4e86-82c4-bfd394c01fcf.jpg
#   inflating: clothing-dataset-small/test/shorts/ee64e502-6a14-44e0-abc9-1692299b00f6.jpg
#   inflating: clothing-dataset-small/test/shorts/56fda6ba-1ee9-4f97-a0fd-55f01f1e2512.jpg
#   inflating: clothing-dataset-small/test/shorts/badd4191-04b8-478f-bb92-83e4cdb67edb.jpg
#   inflating: clothing-dataset-small/test/shorts/2e6303c5-e8ef-4bb3-9ebc-ac97f3ab68d0.jpg
#   inflating: clothing-dataset-small/test/shorts/78d2c5d2-b19d-422a-aff0-a6eb78291b4f.jpg
#   inflating: clothing-dataset-small/test/shorts/06248e28-9e26-4036-8a8f-40cc605c83fb.jpg
#   inflating: clothing-dataset-small/test/shorts/b21eba8d-0bde-44c5-b689-01fbc1ffc4be.jpg
#   inflating: clothing-dataset-small/test/shorts/97620b7f-54ba-445a-9817-b39c8684f890.jpg
#   inflating: clothing-dataset-small/test/shorts/5379356a-40ee-4890-b416-2336a7d84061.jpg
#   inflating: clothing-dataset-small/test/shorts/42862c34-640f-40e1-9187-f2f7749523cd.jpg
#   inflating: clothing-dataset-small/test/shorts/9bc8554c-b0b1-4362-b4ec-783c2ecfcdbd.jpg
#    creating: clothing-dataset-small/test/hat/
#   inflating: clothing-dataset-small/test/hat/7b5181d5-253f-4936-9207-60e3368bf9e1.jpg
#   inflating: clothing-dataset-small/test/hat/ff62e59f-c949-4f8e-8fca-798ab3e174c5.jpg
#   inflating: clothing-dataset-small/test/hat/bcc1aec3-9913-4a2d-b6a0-8f4d97e58b0c.jpg
#   inflating: clothing-dataset-small/test/hat/2a12baab-f020-42e3-8e6b-5d82e3ed0b55.jpg
#   inflating: clothing-dataset-small/test/hat/3f0be386-9a59-4aeb-93f6-dbe63e3a3002.jpg
#   inflating: clothing-dataset-small/test/hat/31ae3916-c352-45fe-9866-a8947fc74991.jpg
#   inflating: clothing-dataset-small/test/hat/78a07855-5a8e-496f-a516-a69e3784bbf1.jpg
#   inflating: clothing-dataset-small/test/hat/c399e385-258a-465c-95d1-ba216c16d7d1.jpg
#   inflating: clothing-dataset-small/test/hat/d116fe9a-a72b-49e2-806d-e92f3a67a032.jpg
#   inflating: clothing-dataset-small/test/hat/bade5af9-c62c-4f10-9b52-c31f50211d48.jpg
#   inflating: clothing-dataset-small/test/hat/a762dfc0-8da7-46d4-9ef1-3c7a085142da.jpg
#   inflating: clothing-dataset-small/test/hat/6c2f18d0-30ff-468c-a470-39c65abf4851.jpg
#    creating: clothing-dataset-small/test/shoes/
#   inflating: clothing-dataset-small/test/shoes/6911b9c4-e3f6-4ff0-9451-610dce3c6ebf.jpg
#   inflating: clothing-dataset-small/test/shoes/73c325ed-47ba-4df3-9b04-d8acab202244.jpg
#   inflating: clothing-dataset-small/test/shoes/9806ff5c-1930-4fb3-a2db-d1bd5a0a6e23.jpg
#   inflating: clothing-dataset-small/test/shoes/b232d13e-54fc-4c3a-9479-040932738ab3.jpg
#   inflating: clothing-dataset-small/test/shoes/dae8c9d7-d344-499e-9253-57bb2a777fe5.jpg
#   inflating: clothing-dataset-small/test/shoes/edaaace7-0a33-49c6-9ed5-1c44e9f02e9d.jpg
#   inflating: clothing-dataset-small/test/shoes/604486df-573b-4eb7-9c78-7b0a5b1b7392.jpg
#   inflating: clothing-dataset-small/test/shoes/a353e037-381a-46a0-b0d6-10e1f1a7ebbe.jpg
#   inflating: clothing-dataset-small/test/shoes/4bef29fd-fa24-44b7-8626-f2230fcd53ed.jpg
#   inflating: clothing-dataset-small/test/shoes/669d3343-bda1-4a33-8f5c-3f20e2807a1f.jpg
#   inflating: clothing-dataset-small/test/shoes/2b54e651-5d43-4f24-9e9e-a58ce16d7c88.jpg
#   inflating: clothing-dataset-small/test/shoes/f3510847-65cb-4b60-8d72-4c02d5ae6c85.jpg
#   inflating: clothing-dataset-small/test/shoes/2d986f3f-de01-498a-9657-68e28c84a6be.jpg
#   inflating: clothing-dataset-small/test/shoes/16fd381e-9da4-493b-aa53-c217eab6bff0.jpg
#   inflating: clothing-dataset-small/test/shoes/6b1c9f42-c52e-4690-836d-d62e66d48ccb.jpg
#   inflating: clothing-dataset-small/test/shoes/a5edfe23-5bb3-48d5-a296-03d0f623d531.jpg
#   inflating: clothing-dataset-small/test/shoes/7e020806-9182-44e5-a9a2-89a88f06f047.jpg
#   inflating: clothing-dataset-small/test/shoes/d4347691-a801-44a8-8e6d-87faea3db2a3.jpg
#   inflating: clothing-dataset-small/test/shoes/d3db25f4-a328-487e-94e9-472bc6f02807.jpg
#   inflating: clothing-dataset-small/test/shoes/9488678d-38f9-4888-b117-28a982ecf6f5.jpg
#   inflating: clothing-dataset-small/test/shoes/ab3238c6-2607-4850-8a17-3e9027867a6c.jpg
#   inflating: clothing-dataset-small/test/shoes/18ff3e0e-6676-4f26-8be4-a992217ac524.jpg
#   inflating: clothing-dataset-small/test/shoes/54120c82-5bb7-4bba-a781-af18362eb24c.jpg
#   inflating: clothing-dataset-small/test/shoes/b5b1359c-f143-4955-a523-25c240777b9b.jpg
#   inflating: clothing-dataset-small/test/shoes/2be8cf7a-5b2e-400f-a826-785997af532a.jpg
#   inflating: clothing-dataset-small/test/shoes/a3afcbf4-8cfc-45ce-88ab-730bdc369cab.jpg
#   inflating: clothing-dataset-small/test/shoes/2174d585-e8cf-43ce-bb61-de1567c74fd5.jpg
#   inflating: clothing-dataset-small/test/shoes/29003421-15e6-41f1-9c65-c0abdfcfaa6e.jpg
#   inflating: clothing-dataset-small/test/shoes/20209905-0830-4a6d-a1cf-7382051f8f18.jpg
#   inflating: clothing-dataset-small/test/shoes/8648344c-5acb-4f5d-93a1-7e89489489bf.jpg
#   inflating: clothing-dataset-small/test/shoes/0dd87e47-ca85-4d5c-9fd1-59f5a01eb656.jpg
#   inflating: clothing-dataset-small/test/shoes/4797602a-efe9-438d-859a-3db113007ef9.jpg
#   inflating: clothing-dataset-small/test/shoes/b6c29a96-b6f5-4b91-ab45-e6727d02ad2d.jpg
#   inflating: clothing-dataset-small/test/shoes/f5ed50b6-79b3-4d9d-84a9-8010f5e1c581.jpg
#   inflating: clothing-dataset-small/test/shoes/562fcdc1-cda7-40cd-bb7b-9b2c908d0931.jpg
#   inflating: clothing-dataset-small/test/shoes/82d149a0-7102-4382-886d-797eb011467b.jpg
#   inflating: clothing-dataset-small/test/shoes/d0ccaaad-7e82-4834-ad38-5dc4440d7e6e.jpg
#   inflating: clothing-dataset-small/test/shoes/264f8d64-c5f0-45ab-9361-8ea9d8e0f5db.jpg
#   inflating: clothing-dataset-small/test/shoes/b94ae406-239e-45d2-a40b-1ec2fb0a8d17.jpg
#   inflating: clothing-dataset-small/test/shoes/4be01935-1fff-4595-aac4-b0a0963b4706.jpg
#   inflating: clothing-dataset-small/test/shoes/15120826-cc4c-44d4-8648-7f334bf5fd69.jpg
#   inflating: clothing-dataset-small/test/shoes/f804b775-13a3-4913-8006-5a1e61f7a005.jpg
#   inflating: clothing-dataset-small/test/shoes/ebb7b9bb-bae5-4865-88c1-3940b7456f40.jpg
#   inflating: clothing-dataset-small/test/shoes/582d11e0-76bc-4ea1-ac4e-9b8dd752e4eb.jpg
#   inflating: clothing-dataset-small/test/shoes/9e042afb-d2cb-49a2-ae53-7cd54995f78d.jpg
#   inflating: clothing-dataset-small/test/shoes/7a84a64a-4fb5-4aa4-8835-96aa2a8dedcf.jpg
#   inflating: clothing-dataset-small/test/shoes/1e170a9f-9437-4eae-bd67-389c48b93ff9.jpg
#   inflating: clothing-dataset-small/test/shoes/e31aa5e7-8b5f-442f-85e3-94225db07928.jpg
#   inflating: clothing-dataset-small/test/shoes/132e5fa5-ed38-4293-8dff-20727b6b5ac2.jpg
#   inflating: clothing-dataset-small/test/shoes/5f838a1c-6ab5-4629-a7cb-4a4755d408bb.jpg
#   inflating: clothing-dataset-small/test/shoes/fcd313d2-0e91-450d-a613-e9f5e91a47da.jpg
#   inflating: clothing-dataset-small/test/shoes/e6230ea8-cef3-4046-bccf-6d78135ad658.jpg
#   inflating: clothing-dataset-small/test/shoes/9b61a6bd-1456-459e-a5f9-00c4c1989b94.jpg
#   inflating: clothing-dataset-small/test/shoes/c236c933-e78f-4e73-8ce6-1630b3a6c91f.jpg
#   inflating: clothing-dataset-small/test/shoes/9111788c-4ef1-41ea-a3c7-95622cd94c55.jpg
#   inflating: clothing-dataset-small/test/shoes/cabd3005-f353-4b1a-8782-a6f298445cfa.jpg
#   inflating: clothing-dataset-small/test/shoes/8dc068c8-245a-4d42-9beb-d704fb7d3feb.jpg
#   inflating: clothing-dataset-small/test/shoes/b554f97c-8eaf-405a-8cbc-b80304c2da94.jpg
#   inflating: clothing-dataset-small/test/shoes/7f3c9738-92af-49a9-92de-b7e762a93e63.jpg
#   inflating: clothing-dataset-small/test/shoes/c79342a6-6642-43f2-9822-a4eb22ebceb6.jpg
#   inflating: clothing-dataset-small/test/shoes/c58c46e1-68e6-4272-8e37-09757b271386.jpg
#   inflating: clothing-dataset-small/test/shoes/2329e4c9-1172-4379-94de-091621a56a40.jpg
#   inflating: clothing-dataset-small/test/shoes/3e35227b-2061-46eb-8379-a6844a4bd5ac.jpg
#   inflating: clothing-dataset-small/test/shoes/cd5db7ac-77b1-4b6d-86f2-3ad1323029c3.jpg
#   inflating: clothing-dataset-small/test/shoes/a0207dce-3e5b-4ac1-92b9-59c6a31c516f.jpg
#   inflating: clothing-dataset-small/test/shoes/98e89103-64e3-41db-adc0-f83726f757d5.jpg
#   inflating: clothing-dataset-small/test/shoes/07d88b75-85a4-407b-aa73-12294a2ff9a8.jpg
#   inflating: clothing-dataset-small/test/shoes/c95edeaa-3884-4be3-b4fd-602782b9ccb5.jpg
#   inflating: clothing-dataset-small/test/shoes/648efd0f-909a-4d07-8ce1-f11a8dceb9cb.jpg
#   inflating: clothing-dataset-small/test/shoes/da73c56d-32ac-4d66-bdb2-82c50adcdde7.jpg
#   inflating: clothing-dataset-small/test/shoes/5d147b66-5238-4ed0-9c6f-c68286fea4ad.jpg
#   inflating: clothing-dataset-small/test/shoes/6f16e53a-4a25-4c8e-9dbf-705c682b1f87.jpg
#   inflating: clothing-dataset-small/test/shoes/bbd52702-8038-4658-bcab-d6ee6586dd01.jpg
#    creating: clothing-dataset-small/test/shirt/
#   inflating: clothing-dataset-small/test/shirt/c0619f0d-9da5-46dc-8b4b-504cc6257223.jpg
#   inflating: clothing-dataset-small/test/shirt/91ac9d20-c473-40c9-adba-15ca13ca173f.jpg
#   inflating: clothing-dataset-small/test/shirt/45814191-3d17-486c-8883-8ddd97b3e7f7.jpg
#   inflating: clothing-dataset-small/test/shirt/8ced139b-54b8-4d7a-b40b-b4cc303bdb62.jpg
#   inflating: clothing-dataset-small/test/shirt/a3d9fa8e-18a0-42a9-a386-0a5e3d23c2e8.jpg
#   inflating: clothing-dataset-small/test/shirt/4cfe336a-6f8c-4f87-a88d-ae4e3897215f.jpg
#   inflating: clothing-dataset-small/test/shirt/5089843a-ecf8-4cb6-8f35-587f19125046.jpg
#   inflating: clothing-dataset-small/test/shirt/3a3a16c8-942d-4541-867b-e97d5a793ea0.jpg
#   inflating: clothing-dataset-small/test/shirt/575fc7c5-aa65-46c6-a343-35113c150129.jpg
#   inflating: clothing-dataset-small/test/shirt/c3ebe8e9-dab4-4e9d-aa83-d9e8a1fcf393.jpg
#   inflating: clothing-dataset-small/test/shirt/cb5e105f-173a-443a-9f54-4b9cbf62919a.jpg
#   inflating: clothing-dataset-small/test/shirt/4758e641-df13-4b3a-93a2-a9e232561c95.jpg
#   inflating: clothing-dataset-small/test/shirt/e1243518-e811-4662-aabb-c2fc5f7d8151.jpg
#   inflating: clothing-dataset-small/test/shirt/0e99edde-0ed8-4c8c-a405-0517c1b801a4.jpg
#   inflating: clothing-dataset-small/test/shirt/adab8f60-032a-4c67-94fc-4d2902a27501.jpg
#   inflating: clothing-dataset-small/test/shirt/ab40ffe9-a4db-41db-8a8a-799f6259d3c0.jpg
#   inflating: clothing-dataset-small/test/shirt/61086848-70bf-462f-87e0-0f756adbd03d.jpg
#   inflating: clothing-dataset-small/test/shirt/83df896e-8d2a-49ac-9944-19bdc6ff70ea.jpg
#   inflating: clothing-dataset-small/test/shirt/69185160-8563-4705-a642-d3002714163b.jpg
#   inflating: clothing-dataset-small/test/shirt/5ec1221f-a52f-4602-9c2c-ed4c81a26708.jpg
#   inflating: clothing-dataset-small/test/shirt/74f6f921-e67e-4562-89ea-c059034c1a31.jpg
#   inflating: clothing-dataset-small/test/shirt/9cedcef4-0138-4386-9fb5-d394971dc2f0.jpg
#   inflating: clothing-dataset-small/test/shirt/01b3083f-4387-4753-8ae2-a2470dc53f19.jpg
#   inflating: clothing-dataset-small/test/shirt/161b57e7-ed65-429a-a795-099b8ce44d08.jpg
#   inflating: clothing-dataset-small/test/shirt/b12d884f-fecc-4134-9626-3088faf1f36d.jpg
#   inflating: clothing-dataset-small/test/shirt/36ad54ae-3450-4264-9655-4de51e6a1a32.jpg
#    creating: clothing-dataset-small/test/outwear/
#   inflating: clothing-dataset-small/test/outwear/77f0e079-e833-4ce9-8220-1142e57de747.jpg
#   inflating: clothing-dataset-small/test/outwear/8f8c07c7-b289-41eb-ac43-9bfb8863e0cb.jpg
#   inflating: clothing-dataset-small/test/outwear/b4af5b70-d260-48b3-8eea-993d762d2dda.jpg
#   inflating: clothing-dataset-small/test/outwear/7f6e85a8-8bc0-4b9f-b3de-23b45c0833d8.jpg
#   inflating: clothing-dataset-small/test/outwear/a1559757-1510-494d-83f0-1fc9c0689170.jpg
#   inflating: clothing-dataset-small/test/outwear/610bc298-714b-4a48-bffe-aedd8863cba8.jpg
#   inflating: clothing-dataset-small/test/outwear/66d29c71-268b-45b8-9ee9-67b280d5f52e.jpg
#   inflating: clothing-dataset-small/test/outwear/7151d08d-0d6a-4648-a304-084bb74c6d1e.jpg
#   inflating: clothing-dataset-small/test/outwear/2edb1db6-cd17-41d2-88e0-ba34801b656d.jpg
#   inflating: clothing-dataset-small/test/outwear/4b319ef4-36eb-431f-8627-dba90b8b3bed.jpg
#   inflating: clothing-dataset-small/test/outwear/fa9f16fa-8b47-4b83-9567-497888652a64.jpg
#   inflating: clothing-dataset-small/test/outwear/efbc5815-d1d4-4d85-8df2-9d9caae4300b.jpg
#   inflating: clothing-dataset-small/test/outwear/d7c67097-288d-4d10-b6cb-11d97c1507b2.jpg
#   inflating: clothing-dataset-small/test/outwear/0028956e-9962-46f0-ad45-2c42f8a59d94.jpg
#   inflating: clothing-dataset-small/test/outwear/01e4ab4f-6148-4dd7-9a43-df7681fbc71d.jpg
#   inflating: clothing-dataset-small/test/outwear/26d61cdc-a947-45f1-a16c-bf3eb23a67ed.jpg
#   inflating: clothing-dataset-small/test/outwear/69974463-ccef-4326-9df4-beac048309cb.jpg
#   inflating: clothing-dataset-small/test/outwear/0d73e759-eeaa-43ab-98d4-196b6974c41e.jpg
#   inflating: clothing-dataset-small/test/outwear/f1784f1b-61c7-4bd8-9799-3bed700857bb.jpg
#   inflating: clothing-dataset-small/test/outwear/1dcf0cd4-ca7e-46ac-90c7-ce465153a7f0.jpg
#   inflating: clothing-dataset-small/test/outwear/fbe119df-fd65-46c0-aab7-f9f5de8878bc.jpg
#   inflating: clothing-dataset-small/test/outwear/c99c0a08-e27a-49a7-a24e-f088ff9ac3ce.jpg
#   inflating: clothing-dataset-small/test/outwear/b167f39f-eea8-4f69-9494-e2346bd7e2c5.jpg
#   inflating: clothing-dataset-small/test/outwear/105c3674-f1d0-4fc6-8131-e53001670352.jpg
#   inflating: clothing-dataset-small/test/outwear/8a17d01f-80f9-4e88-ad35-51d09dbb5b3c.jpg
#   inflating: clothing-dataset-small/test/outwear/e36dcac4-c66b-4120-b828-89bfc0110716.jpg
#   inflating: clothing-dataset-small/test/outwear/0a86d893-93f1-4a52-8c42-07bb9f439833.jpg
#   inflating: clothing-dataset-small/test/outwear/ae6cf708-9abd-4422-9c4e-6cf3b6200031.jpg
#   inflating: clothing-dataset-small/test/outwear/5641733d-73ff-4ba6-9cfe-5212b1f190be.jpg
#   inflating: clothing-dataset-small/test/outwear/b8f3af98-e650-4f59-a3f3-513a1c5ec418.jpg
#   inflating: clothing-dataset-small/test/outwear/ec0a2f9b-99ca-48bf-bb0a-b10748f57fda.jpg
#   inflating: clothing-dataset-small/test/outwear/463bbfd1-880b-4537-abb8-8ef98c2894c5.jpg
#   inflating: clothing-dataset-small/test/outwear/5272341c-6438-491d-ab64-44db18de7e28.jpg
#   inflating: clothing-dataset-small/test/outwear/7e96c66c-bbd2-47af-8c2d-a510e52c680f.jpg
#   inflating: clothing-dataset-small/test/outwear/5a9be8ea-9c5c-459b-9b5b-7adb4a0e2867.jpg
#   inflating: clothing-dataset-small/test/outwear/f315fe31-fa7a-4c1d-a461-3e67ffe6f981.jpg
#   inflating: clothing-dataset-small/test/outwear/9ce16112-faef-414a-8021-a93388421dc4.jpg
#   inflating: clothing-dataset-small/test/outwear/c830bb15-ad3b-406a-ab50-4d30e5b95a41.jpg
#    creating: clothing-dataset-small/train/
#    creating: clothing-dataset-small/train/skirt/
#   inflating: clothing-dataset-small/train/skirt/fdbcfdcd-5deb-4a20-9aef-b708831ef774.jpg
#   inflating: clothing-dataset-small/train/skirt/bd289469-607c-45df-bad3-ed1057e277bf.jpg
#   inflating: clothing-dataset-small/train/skirt/6b6416d0-7fae-4858-ba58-f0420302a1b2.jpg
#   inflating: clothing-dataset-small/train/skirt/ec5f9167-6824-43cf-9f91-15c99a9318c4.jpg
#   inflating: clothing-dataset-small/train/skirt/a6a301fe-74f4-4a22-9847-a6f6ce98aa4b.jpg
#   inflating: clothing-dataset-small/train/skirt/26921ddb-5f3e-4878-a156-3318f4d831b0.jpg
#   inflating: clothing-dataset-small/train/skirt/53c395a3-94bf-4ad9-be75-3bb3924c2d76.jpg
#   inflating: clothing-dataset-small/train/skirt/58d7105d-ec37-4cda-8bf8-7dd2c7b1bf6e.jpg
#   inflating: clothing-dataset-small/train/skirt/0da586b0-bbfb-44fd-a629-12aee2b1d430.jpg
#   inflating: clothing-dataset-small/train/skirt/4d4f6900-da14-4e6c-9236-e3a98261fdc2.jpg
#   inflating: clothing-dataset-small/train/skirt/f443ff4d-4d7f-47d9-9288-61f2594343d7.jpg
#   inflating: clothing-dataset-small/train/skirt/d44cfac9-3fda-47ba-8eb1-8b130f60b08c.jpg
#   inflating: clothing-dataset-small/train/skirt/6d210194-60de-49c5-a215-05201cfa1a64.jpg
#   inflating: clothing-dataset-small/train/skirt/ce118595-1373-463c-9be5-0b7d62ce1f0d.jpg
#   inflating: clothing-dataset-small/train/skirt/abc109d6-6bb8-4772-8258-6dd92d9d86c1.jpg
#   inflating: clothing-dataset-small/train/skirt/a122ba8d-6ebe-42f8-8f72-433aa1a6740a.jpg
#   inflating: clothing-dataset-small/train/skirt/2a79969e-c45d-432f-a62b-90970e4d909f.jpg
#   inflating: clothing-dataset-small/train/skirt/29a50158-569c-4597-ab58-184fa0256c51.jpg
#   inflating: clothing-dataset-small/train/skirt/0903f4c9-a877-4832-bb9e-2a4f4b8f7f67.jpg
#   inflating: clothing-dataset-small/train/skirt/8a34360e-9feb-4571-8e16-01d90f6576c7.jpg
#   inflating: clothing-dataset-small/train/skirt/672b0d76-2277-4edf-8903-51cd6646b139.jpg
#   inflating: clothing-dataset-small/train/skirt/8361e496-70e5-4499-afce-d01848b1d5e8.jpg
#   inflating: clothing-dataset-small/train/skirt/a0734f9e-9f67-4d45-a00b-26e65700d157.jpg
#   inflating: clothing-dataset-small/train/skirt/22d78476-595a-412d-861e-880264696556.jpg
#   inflating: clothing-dataset-small/train/skirt/085469ab-cdb6-42e6-a3cf-f370b6b6ddd6.jpg
#   inflating: clothing-dataset-small/train/skirt/2503103d-48e1-4be1-b90e-c2e80b5f1eed.jpg
#   inflating: clothing-dataset-small/train/skirt/c1df0487-20c3-4acc-a0d8-cfbf14942e2a.jpg
#   inflating: clothing-dataset-small/train/skirt/af5c0e7c-d950-4e6f-88ac-642a41a27b75.jpg
#   inflating: clothing-dataset-small/train/skirt/574a2370-af89-4c9a-bbb9-9acfd31489f3.jpg
#   inflating: clothing-dataset-small/train/skirt/31fd2f8b-620c-405d-b9f9-5e676dbace96.jpg
#   inflating: clothing-dataset-small/train/skirt/def00273-79ed-414b-b7d3-d742001a2d15.jpg
#   inflating: clothing-dataset-small/train/skirt/ccb57961-f839-44fc-be22-8b8a5944f8b3.jpg
#   inflating: clothing-dataset-small/train/skirt/0ab26941-211e-44d7-a62a-20207fa7a3e0.jpg
#   inflating: clothing-dataset-small/train/skirt/86d25b2c-d388-49f6-9616-d2ad838c7148.jpg
#   inflating: clothing-dataset-small/train/skirt/5e2b335d-2f5e-4356-9aba-a735af742b6a.jpg
#   inflating: clothing-dataset-small/train/skirt/1d08ddfe-dfd4-4bf9-81a7-9cc8dfa2833f.jpg
#   inflating: clothing-dataset-small/train/skirt/db36b9f3-57d5-4840-8d67-89c2f8a03251.jpg
#   inflating: clothing-dataset-small/train/skirt/8ede80c5-5604-4d69-9c1a-4aa7711a02ec.jpg
#   inflating: clothing-dataset-small/train/skirt/36e2b110-6be7-4c46-a865-34ca99808c11.jpg
#   inflating: clothing-dataset-small/train/skirt/2f8687c7-bdbf-449f-8528-639040681663.jpg
#   inflating: clothing-dataset-small/train/skirt/25450d12-43a6-48c1-b5c0-fd613ad61ee0.jpg
#   inflating: clothing-dataset-small/train/skirt/97297d04-884f-451b-b75a-717ce3d1442a.jpg
#   inflating: clothing-dataset-small/train/skirt/284149a9-e71e-4955-8228-7511fa592bc1.jpg
#   inflating: clothing-dataset-small/train/skirt/16dae877-412a-489e-8935-4bd08db2fa23.jpg
#   inflating: clothing-dataset-small/train/skirt/cb3838a8-f6e4-4845-8140-51ff740a75cb.jpg
#   inflating: clothing-dataset-small/train/skirt/41e11790-a772-47b1-b251-15c3464038b7.jpg
#   inflating: clothing-dataset-small/train/skirt/bb437c07-06e4-4b16-b3aa-8382dd35de0a.jpg
#   inflating: clothing-dataset-small/train/skirt/f309b378-084e-4709-9519-7087175395ca.jpg
#   inflating: clothing-dataset-small/train/skirt/9b96c318-a9bf-446f-873e-6388906cce86.jpg
#   inflating: clothing-dataset-small/train/skirt/39dc8452-9d13-4941-a1e2-fc05df87ee4c.jpg
#   inflating: clothing-dataset-small/train/skirt/78b7da73-ca6c-4e99-b88d-a9f358e7f0f2.jpg
#   inflating: clothing-dataset-small/train/skirt/c763b1d1-ed61-4545-b740-501363ca613f.jpg
#   inflating: clothing-dataset-small/train/skirt/104b1054-3d95-4738-8199-d4b0581e735f.jpg
#   inflating: clothing-dataset-small/train/skirt/77cd4632-d981-4254-9134-08e44dab9834.jpg
#   inflating: clothing-dataset-small/train/skirt/7e77ec6d-2bd6-45c7-9904-cf1fae288afc.jpg
#   inflating: clothing-dataset-small/train/skirt/6fb5a560-4000-43f6-b656-f61cf0a8649e.jpg
#   inflating: clothing-dataset-small/train/skirt/84ae684a-cb1c-46e7-ba47-b6519e4f0d51.jpg
#   inflating: clothing-dataset-small/train/skirt/011ecf12-aab1-4c72-8f77-2649386cd23b.jpg
#   inflating: clothing-dataset-small/train/skirt/567298c6-e892-4aa3-bac6-4f8993ee23c0.jpg
#   inflating: clothing-dataset-small/train/skirt/f66f8334-fa7c-44fb-a9db-2f4b0b407cf0.jpg
#   inflating: clothing-dataset-small/train/skirt/4845b1d5-2535-43d8-90b0-dbc10002bcb8.jpg
#   inflating: clothing-dataset-small/train/skirt/c3310cf3-b4f0-4d4b-b616-8fdc930ce074.jpg
#   inflating: clothing-dataset-small/train/skirt/55808c24-c583-4bb5-91a1-6dca3056faf2.jpg
#   inflating: clothing-dataset-small/train/skirt/942987de-bfc1-41eb-be1e-e01d7f98f7a4.jpg
#   inflating: clothing-dataset-small/train/skirt/805a7767-cec7-4323-9a75-6c5c2024479d.jpg
#   inflating: clothing-dataset-small/train/skirt/2d758bb1-1a3b-4240-8fc0-ca9647ccba5d.jpg
#   inflating: clothing-dataset-small/train/skirt/389bb7fe-02a7-4db4-9daa-1604b5ca8cb1.jpg
#   inflating: clothing-dataset-small/train/skirt/84e4d60a-a684-4b88-b86e-dfac84cfac92.jpg
#   inflating: clothing-dataset-small/train/skirt/8a7353cf-f8e3-4a73-b72e-239ed04d4e2d.jpg
#   inflating: clothing-dataset-small/train/skirt/6da4653c-905d-4257-aa82-824afda0c0a5.jpg
#   inflating: clothing-dataset-small/train/skirt/cf9d6ed6-7325-425e-be2b-bb5a6bc43fbe.jpg
#   inflating: clothing-dataset-small/train/skirt/b524ee06-ab17-4e0f-8e79-40d12c275d92.jpg
#   inflating: clothing-dataset-small/train/skirt/f3307762-77ad-4bb0-b50a-c3d661dfa8b1.jpg
#   inflating: clothing-dataset-small/train/skirt/69d4e9dd-3176-413f-8bff-fa9f8129e01c.jpg
#   inflating: clothing-dataset-small/train/skirt/f1ff2780-2ab1-401f-8089-089b5dfa1cf2.jpg
#   inflating: clothing-dataset-small/train/skirt/ec1fbb96-442d-42b3-a5d1-46bd1d86bc24.jpg
#   inflating: clothing-dataset-small/train/skirt/8d173264-bc7d-4175-8130-711c94d3f1ca.jpg
#   inflating: clothing-dataset-small/train/skirt/12f6208b-331e-4257-bcfe-bb48f8c924aa.jpg
#   inflating: clothing-dataset-small/train/skirt/3ac953dd-31fb-461f-8bbd-7802397cc392.jpg
#   inflating: clothing-dataset-small/train/skirt/9e530520-3973-44d0-b630-e213c809b854.jpg
#   inflating: clothing-dataset-small/train/skirt/0570064d-b6cf-48a5-a703-f217d8a38333.jpg
#   inflating: clothing-dataset-small/train/skirt/c938f1ac-6e47-41a9-8546-9ca7c27477aa.jpg
#   inflating: clothing-dataset-small/train/skirt/f9c7e0bc-dfde-4720-b6bd-64bfeb2c55fa.jpg
#   inflating: clothing-dataset-small/train/skirt/740e3cc1-3b71-454d-9fc9-6cff9a46f3b2.jpg
#   inflating: clothing-dataset-small/train/skirt/667a7349-f0a7-43bc-bb70-246b61e6354b.jpg
#   inflating: clothing-dataset-small/train/skirt/628d1234-90c7-41fd-b761-2697b5b528c9.jpg
#   inflating: clothing-dataset-small/train/skirt/7ec3c84f-6c41-40bf-8248-f89846c6be6c.jpg
#   inflating: clothing-dataset-small/train/skirt/910268c2-a132-4d25-80b1-59812c52e65c.jpg
#   inflating: clothing-dataset-small/train/skirt/637a56e4-7fa6-4f75-8859-0f8902461554.jpg
#   inflating: clothing-dataset-small/train/skirt/cec644db-b07c-4420-8199-f5bdd8ea3f83.jpg
#   inflating: clothing-dataset-small/train/skirt/02341619-2fa3-42d4-bb5e-689518228e67.jpg
#   inflating: clothing-dataset-small/train/skirt/ea6195ca-94fd-4ffa-b133-81f56df1d446.jpg
#   inflating: clothing-dataset-small/train/skirt/978f5148-3c6b-4393-9d12-df98d51b8881.jpg
#   inflating: clothing-dataset-small/train/skirt/6f7e039f-85a2-47dd-9cc2-b2cbd64367a5.jpg
#   inflating: clothing-dataset-small/train/skirt/e352b5ea-5975-486d-bd66-82bb5aafec9d.jpg
#   inflating: clothing-dataset-small/train/skirt/a12ecb02-bca3-4253-b3fd-e3d19765f770.jpg
#   inflating: clothing-dataset-small/train/skirt/e3d30ea5-976b-45a8-a1e4-0fbcc7a045c2.jpg
#   inflating: clothing-dataset-small/train/skirt/8b2ef33f-4b74-4967-9b9e-42345b599397.jpg
#   inflating: clothing-dataset-small/train/skirt/48895e87-ae51-4c7e-98ae-2855991264d1.jpg
#   inflating: clothing-dataset-small/train/skirt/ee0fde64-aac5-4904-a8df-921864d7c01c.jpg
#   inflating: clothing-dataset-small/train/skirt/9fcc508a-3a8a-4321-8016-0f734fd13700.jpg
#   inflating: clothing-dataset-small/train/skirt/55ffc997-f56f-4b2d-b57f-2d25956d5c74.jpg
#   inflating: clothing-dataset-small/train/skirt/781887ea-b7fd-4271-9b7d-8b372badfacf.jpg
#   inflating: clothing-dataset-small/train/skirt/70045b01-b350-4918-be74-2f627290ad7a.jpg
#   inflating: clothing-dataset-small/train/skirt/bc34145a-3844-4c08-a7a2-c45321541f57.jpg
#   inflating: clothing-dataset-small/train/skirt/f8b84112-9110-4628-91e8-9d22a13767f3.jpg
#   inflating: clothing-dataset-small/train/skirt/d44c49f4-e694-4ee6-a839-1579543b8e04.jpg
#   inflating: clothing-dataset-small/train/skirt/038e4976-e75f-452e-bccc-2ebb5d5c0e0a.jpg
#   inflating: clothing-dataset-small/train/skirt/49e9555c-f96e-4887-90e5-036b4d908c64.jpg
#   inflating: clothing-dataset-small/train/skirt/ecf2db5b-2a36-4716-8a06-85c6f33e6b08.jpg
#   inflating: clothing-dataset-small/train/skirt/125472d8-0f0a-4d45-b531-fb87a9d9d95e.jpg
#   inflating: clothing-dataset-small/train/skirt/0f8c39ba-e2b1-4c94-be5e-6ac2d924f7ed.jpg
#    creating: clothing-dataset-small/train/longsleeve/
#   inflating: clothing-dataset-small/train/longsleeve/5c1b7a77-1fa3-4af8-9722-cd38e45d89da.jpg
#   inflating: clothing-dataset-small/train/longsleeve/d9e84490-185d-48f9-ac16-4ef3360616d5.jpg
#   inflating: clothing-dataset-small/train/longsleeve/8f576f1a-839d-4fb2-a224-a4700b2d05da.jpg
#   inflating: clothing-dataset-small/train/longsleeve/bbf0d9c7-663d-46d1-a9f8-66e8e5678541.jpg
#   inflating: clothing-dataset-small/train/longsleeve/049e77f5-2a28-457a-9d27-2edb3da2fd7f.jpg
#   inflating: clothing-dataset-small/train/longsleeve/cd6ff00a-3441-4977-a35b-7935cd4331c0.jpg
#   inflating: clothing-dataset-small/train/longsleeve/4338519e-515a-46e2-8443-4d3213426d2e.jpg
#   inflating: clothing-dataset-small/train/longsleeve/e6abee3d-9e61-4f3f-b523-3f1a1264ab8f.jpg
#   inflating: clothing-dataset-small/train/longsleeve/bfb072bd-4378-47d5-ad94-e11e367fbdd0.jpg
#   inflating: clothing-dataset-small/train/longsleeve/bd80bf28-cacb-438c-af31-8ffd7c557a9a.jpg
#   inflating: clothing-dataset-small/train/longsleeve/29e42d8d-ea01-40d3-b82b-002c4343ed93.jpg
#   inflating: clothing-dataset-small/train/longsleeve/78d2f207-515d-4252-83df-7a3a4fe179cf.jpg
#   inflating: clothing-dataset-small/train/longsleeve/a36dc7ad-29ab-4c1f-9701-45143aeb5424.jpg
#   inflating: clothing-dataset-small/train/longsleeve/2b41ceef-e71c-4229-86fc-e7b50a6ef8c5.jpg
#   inflating: clothing-dataset-small/train/longsleeve/f6943183-e0e0-4b1b-a11b-451941bc523f.jpg
#   inflating: clothing-dataset-small/train/longsleeve/5af25198-5449-4f01-8155-21192662397c.jpg
#   inflating: clothing-dataset-small/train/longsleeve/38bf9790-f653-453b-96b4-72a298413eb7.jpg
#   inflating: clothing-dataset-small/train/longsleeve/893c3f24-4bd7-45bc-995f-cb85847c92c5.jpg
#   inflating: clothing-dataset-small/train/longsleeve/d6f795ec-6296-42b7-99a4-705121546943.jpg
#   inflating: clothing-dataset-small/train/longsleeve/06c96380-f7bc-46ca-a3fc-9288181f1f69.jpg
#   inflating: clothing-dataset-small/train/longsleeve/0142c777-baf8-4500-add9-6641b95b90ec.jpg
#   inflating: clothing-dataset-small/train/longsleeve/107dd572-7136-4eac-a255-1883467e6a62.jpg
#   inflating: clothing-dataset-small/train/longsleeve/cafa5744-0273-438b-8a52-cb294c13ac42.jpg
#   inflating: clothing-dataset-small/train/longsleeve/0e20abb0-d56a-4f83-b254-9db70fb92794.jpg
#   inflating: clothing-dataset-small/train/longsleeve/55642545-7055-4b8b-aa89-a2cf4233016e.jpg
#   inflating: clothing-dataset-small/train/longsleeve/1823c84a-dc6f-4edc-ae75-b54303132369.jpg
#   inflating: clothing-dataset-small/train/longsleeve/17a8b1aa-5aaa-47ac-8de1-5d2c9d0f83f1.jpg
#   inflating: clothing-dataset-small/train/longsleeve/2f891a3a-b53c-4619-92a0-51236080811c.jpg
#   inflating: clothing-dataset-small/train/longsleeve/4b59aac5-4659-4d41-bdb1-b18f413f70fc.jpg
#   inflating: clothing-dataset-small/train/longsleeve/582f7f10-e2bb-4cc4-9fb7-829e71dc0f02.jpg
# ...
#   inflating: clothing-dataset-small/validation/t-shirt/3861b881-90d1-446d-ad1a-8b93e96dc935.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/f8b7bdad-76ce-4efc-a26c-6a9d625d91fe.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/aa6bb957-1ab8-4590-80d8-e9d825ffd6ff.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/2952baa3-1c19-4629-aac5-48f9c123f4b1.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/ce1c9b72-9889-41cd-8ed1-e6eb4305af68.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/a5e1addc-13cf-4d7e-be46-dfefa23beee4.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/2ae08b28-adf9-4fc8-b150-513cad510b1e.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/7ed92e7c-ad0c-4e83-b5ac-15d564f7628e.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/76f8420a-bcea-4bb8-a049-befa05315470.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/28709ef4-cebf-40c5-8347-f59932bf9323.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/f84f31e8-449e-41e4-aab8-f874ac1ff31f.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/a9b25869-8ee5-4fbd-b3e8-e5067c5f73e7.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/47533149-1373-4576-9d70-8b4bf33a687c.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/fb5dd646-6a9e-4666-ab78-74b463431f54.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/5ab59471-f2f5-4ff9-a106-3de7044fbfd2.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/e527e508-fe15-4369-a497-0134a03c755d.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/99fdccb7-216b-46ce-88fd-15e79bccdeac.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/099de1d5-7422-4230-b11b-fe581139b82c.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/275874a1-4cfd-4852-a751-24cf7f666517.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/950ed785-66d7-4f9b-99e7-925641ecad2b.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/aafe2f1b-6257-44ac-b1ef-7c9ad90a64f3.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/27e1dfc7-4a9a-4049-ad9c-253535a92b94.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/8219480b-f427-49ce-b823-2119278c42cd.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/7c57af11-6b27-4995-8b4b-1a42afd6b9e3.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/1ab00c0e-4fc7-45d4-b9af-7d1bd75e1fd9.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/fadaa2b4-58dc-4eb8-88b4-941a5b3c6e20.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/12a48c81-d35b-45f8-93fd-5d69153163e2.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/2b8f8ba1-9264-4eeb-bdf5-0a141490db17.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/788d20a1-ad98-46fe-b80d-af9fd32a4e0f.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/2ce576f8-cb93-43ee-933b-22d1c6d1678f.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/b40fd43d-6c94-41d2-b107-fe98fa633ea9.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/2324306f-d9a3-47b7-b648-8684b8aca35c.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/4a9ce2fd-5ffb-438a-93d6-83463910b87a.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/09cd8fdf-bbe9-4908-8f54-f399bc635c9b.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/8d5b6ef2-bc6f-4364-a278-580a5d91c7d7.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/16f1fbdf-d339-40f6-aecb-e55199db7a96.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/a45a4d15-bc24-432b-912e-eb81eba16ef1.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/0e240297-2265-411e-b386-cb59a44f98ae.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/e221fe90-ab6f-437b-9b0b-9a4f995c2bad.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/3e33ad0d-e342-429c-89bd-fb1ece1a4065.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/d90835e2-e433-4c1b-a43f-4a6ba0f9617a.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/e44b1445-0f43-4387-a8d6-e9c2d46de5ec.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/8d3ec813-014f-4a8b-ab08-bc21dfb9823e.jpg
#   inflating: clothing-dataset-small/validation/t-shirt/c5371dda-ab7d-4bfc-9b5b-275c579e3f94.jpg
#    creating: clothing-dataset-small/validation/shorts/
#   inflating: clothing-dataset-small/validation/shorts/73d0010c-e5f1-49aa-bc8d-222002cdb5b6.jpg
#   inflating: clothing-dataset-small/validation/shorts/e55c3d9f-81f8-4e0c-9882-3a747ed4c676.jpg
#   inflating: clothing-dataset-small/validation/shorts/f051ba41-a8e9-4898-b430-f75d8578041e.jpg
#   inflating: clothing-dataset-small/validation/shorts/f31fd334-0aef-4c15-aba0-92aa541013b2.jpg
#   inflating: clothing-dataset-small/validation/shorts/6505e289-1236-4675-8430-ebcc52fe4ca6.jpg
#   inflating: clothing-dataset-small/validation/shorts/0fc5edba-525c-4234-935f-af55b39530dc.jpg
#   inflating: clothing-dataset-small/validation/shorts/8a763700-8a1a-4396-947d-d1264e2005ee.jpg
#   inflating: clothing-dataset-small/validation/shorts/2e11ac6b-d3ac-4368-b499-9beea54388a4.jpg
#   inflating: clothing-dataset-small/validation/shorts/1dbe9268-758f-4cd4-8f42-58b40ef4bb74.jpg
#   inflating: clothing-dataset-small/validation/shorts/17e1cea3-4010-4f4f-b7a4-77d96594e219.jpg
#   inflating: clothing-dataset-small/validation/shorts/6b825ceb-4d84-4fa2-8953-af936b3233ac.jpg
#   inflating: clothing-dataset-small/validation/shorts/73074cee-871e-4b79-8b25-197bb404e7d3.jpg
#   inflating: clothing-dataset-small/validation/shorts/27f3c569-0b20-4791-a39e-54a3c6e16da1.jpg
#   inflating: clothing-dataset-small/validation/shorts/c6689216-f1cf-4b72-9711-c9c81ee31618.jpg
#   inflating: clothing-dataset-small/validation/shorts/9de18803-34d3-4737-b958-075a1ffadbc1.jpg
#   inflating: clothing-dataset-small/validation/shorts/a5fa97cf-e45e-4a14-a001-93276576a58d.jpg
#   inflating: clothing-dataset-small/validation/shorts/3e203f7a-5b90-4b27-9303-a5634a80f015.jpg
#   inflating: clothing-dataset-small/validation/shorts/fa8d1daa-7813-4f98-a944-915418385ee9.jpg
#   inflating: clothing-dataset-small/validation/shorts/f53c2e58-848e-4185-98f8-e0bb416f1d42.jpg
#   inflating: clothing-dataset-small/validation/shorts/273d37f5-1f5f-4ab2-bfbf-1e5a4648500c.jpg
#   inflating: clothing-dataset-small/validation/shorts/0c4d3d88-9756-4211-83ad-2d6c68ea0043.jpg
#   inflating: clothing-dataset-small/validation/shorts/0e88c86f-911f-4dd6-85b6-cb953e9dd2c5.jpg
#   inflating: clothing-dataset-small/validation/shorts/671603f9-b503-4d14-a389-3c46ff8bf163.jpg
#   inflating: clothing-dataset-small/validation/shorts/456578a1-8a2e-4906-85a4-c93ceef8c108.jpg
#   inflating: clothing-dataset-small/validation/shorts/163d946e-7638-4069-92e0-1b02be330271.jpg
#    creating: clothing-dataset-small/validation/hat/
#   inflating: clothing-dataset-small/validation/hat/4f04a31f-6589-4fe2-8a95-a42f6a164bd9.jpg
#   inflating: clothing-dataset-small/validation/hat/98daa3f5-8a8b-43ad-b7df-b7f63dfb7c04.jpg
#   inflating: clothing-dataset-small/validation/hat/e15db3d5-25ff-42d2-bde0-6c9547bfff6b.jpg
#   inflating: clothing-dataset-small/validation/hat/50cf0bbc-5a25-4df9-94fe-3323d2b61bff.jpg
#   inflating: clothing-dataset-small/validation/hat/d7c07f9f-8362-4abc-92aa-193221a7db5b.jpg
#   inflating: clothing-dataset-small/validation/hat/8f809fea-1f7d-4695-be36-a061bd77c170.jpg
#   inflating: clothing-dataset-small/validation/hat/7c28df10-5bfc-4deb-b57f-6c292f07b98b.jpg
#   inflating: clothing-dataset-small/validation/hat/7bfaa9c2-d467-4627-9ff4-233075aa65d4.jpg
#   inflating: clothing-dataset-small/validation/hat/d56b676e-1f28-4c56-96d6-070237e2a43f.jpg
#   inflating: clothing-dataset-small/validation/hat/86a3f65f-8c08-48b6-a783-0e38ffa006ef.jpg
#   inflating: clothing-dataset-small/validation/hat/7b4ca4a5-fd04-4a96-9f40-1a982ff6cb8b.jpg
#   inflating: clothing-dataset-small/validation/hat/d9024c75-93f8-4b22-aeff-f7966d924c57.jpg
#   inflating: clothing-dataset-small/validation/hat/de697750-a1ce-4595-8836-47e5be76d1da.jpg
#   inflating: clothing-dataset-small/validation/hat/014b2a1b-c5a0-469b-b115-bc02b2001db5.jpg
#    creating: clothing-dataset-small/validation/shoes/
#   inflating: clothing-dataset-small/validation/shoes/253dc2b9-f49e-4f55-9917-c9005c29bbd9.jpg
#   inflating: clothing-dataset-small/validation/shoes/dc0d9ba1-165e-46d8-bdb1-fba1d753ead8.jpg
#   inflating: clothing-dataset-small/validation/shoes/4eba049d-e813-4af9-913a-53b6877cdda2.jpg
#   inflating: clothing-dataset-small/validation/shoes/24535295-abe3-4613-91f6-a7fe87954662.jpg
#   inflating: clothing-dataset-small/validation/shoes/8e3553a1-859e-4e56-a7b5-154a0b1c2c57.jpg
#   inflating: clothing-dataset-small/validation/shoes/5e577f40-dd22-4b40-9827-ce6cae5ac3fd.jpg
#   inflating: clothing-dataset-small/validation/shoes/41302a0b-5faf-48a9-9b40-33885d28a7a6.jpg
#   inflating: clothing-dataset-small/validation/shoes/6cb6102f-cf2a-4b60-8b44-97e8b8e1e4f2.jpg
#   inflating: clothing-dataset-small/validation/shoes/e454baf3-5081-42fe-a145-e244e9a5edd2.jpg
#   inflating: clothing-dataset-small/validation/shoes/e787428b-ff3b-4018-8fbd-bff485db291d.jpg
#   inflating: clothing-dataset-small/validation/shoes/65368501-a7a8-4552-9035-7e812b9b4828.jpg
#   inflating: clothing-dataset-small/validation/shoes/d9218439-14f1-46fa-8c35-f17f112b08fe.jpg
#   inflating: clothing-dataset-small/validation/shoes/454fd50e-89eb-412b-b16c-17f1730ed9b5.jpg
#   inflating: clothing-dataset-small/validation/shoes/e9c4090d-6f3a-4142-bd36-e5eebc57d641.jpg
#   inflating: clothing-dataset-small/validation/shoes/b34268f1-78ad-4e58-bc16-2aa0728c1f7b.jpg
#   inflating: clothing-dataset-small/validation/shoes/feb9c05f-55c1-465f-9b13-3c933302a91c.jpg
#   inflating: clothing-dataset-small/validation/shoes/e92b0f2e-dbe8-4d22-a26c-8d81640b739b.jpg
#   inflating: clothing-dataset-small/validation/shoes/62309a10-d8ff-4f5c-bfb5-85ed0c2682dc.jpg
#   inflating: clothing-dataset-small/validation/shoes/e4426e67-a4b0-430f-81cb-3ea2c8544027.jpg
#   inflating: clothing-dataset-small/validation/shoes/6ce1572f-bf7a-4940-8b4f-611cbac3f8ce.jpg
#   inflating: clothing-dataset-small/validation/shoes/7d5a20ff-6431-404e-9870-78140166cf7a.jpg
#   inflating: clothing-dataset-small/validation/shoes/32662cf1-4440-459c-b55c-0ba39b71f768.jpg
#   inflating: clothing-dataset-small/validation/shoes/873dcb7d-34db-488c-b29e-1bbf78102a23.jpg
#   inflating: clothing-dataset-small/validation/shoes/5bb088ac-ea91-419b-851e-1b04b7ce57db.jpg
#   inflating: clothing-dataset-small/validation/shoes/7bb0226b-f068-4b46-9e40-1e5110319fcd.jpg
#   inflating: clothing-dataset-small/validation/shoes/c1480bd3-e7cb-421e-a58b-1b3cb7e4ff27.jpg
#    creating: clothing-dataset-small/validation/shirt/
#   inflating: clothing-dataset-small/validation/shirt/ee23222a-f46f-4044-abb2-0a5d1795da36.jpg
#   inflating: clothing-dataset-small/validation/shirt/5d97eab8-e62b-49cf-b73e-7cec4951d9c2.jpg
#   inflating: clothing-dataset-small/validation/shirt/00143901-a14c-4600-960f-7747b4a3a8cd.jpg
#   inflating: clothing-dataset-small/validation/shirt/619655e3-2925-4ff3-94d6-f0e2d3f78b2f.jpg
#   inflating: clothing-dataset-small/validation/shirt/b09b92a8-4e52-4ac6-946b-6b8fbf83898f.jpg
#   inflating: clothing-dataset-small/validation/shirt/309ead9a-2672-40b7-8a09-ab5fc6abccc0.jpg
#   inflating: clothing-dataset-small/validation/shirt/6dd9f374-da25-4bc8-9bbf-39693da3a266.jpg
#   inflating: clothing-dataset-small/validation/shirt/29f8cf36-3ae6-4558-9f42-82f330c15b3d.jpg
#   inflating: clothing-dataset-small/validation/shirt/a85064d6-0f5d-4fce-9e3a-d1b5902c6098.jpg
#   inflating: clothing-dataset-small/validation/shirt/0e7453e0-023c-4c34-b837-e6349846b112.jpg
#   inflating: clothing-dataset-small/validation/shirt/f6b3d8e8-af0b-4cdd-b821-6df326152dbf.jpg
#   inflating: clothing-dataset-small/validation/shirt/235230d6-8a23-4981-bc43-5e62c0570f44.jpg
#   inflating: clothing-dataset-small/validation/shirt/1d2e0956-07d7-41d8-9286-ea98d1d32dbd.jpg
#   inflating: clothing-dataset-small/validation/shirt/cad0e833-619e-4517-91ce-938497622c12.jpg
#   inflating: clothing-dataset-small/validation/shirt/e7ec7ab5-494f-417c-a0ce-c7bbef93d745.jpg
#   inflating: clothing-dataset-small/validation/shirt/eff90bf7-9cfc-48f2-ad96-d4638e336da1.jpg
#   inflating: clothing-dataset-small/validation/shirt/328e21ed-2843-4469-a49d-4c01470dc98d.jpg
#   inflating: clothing-dataset-small/validation/shirt/e3f59ab5-daa0-4acf-a114-c6fae6afef56.jpg
#   inflating: clothing-dataset-small/validation/shirt/31315e30-2742-4f7f-8168-10a0645d2163.jpg
#   inflating: clothing-dataset-small/validation/shirt/4db14d3d-05ca-48b1-9257-204b447c27bb.jpg
#   inflating: clothing-dataset-small/validation/shirt/832898d6-3ac7-472b-835b-4dd3e5843342.jpg
#   inflating: clothing-dataset-small/validation/shirt/ea0cfac2-165d-45ab-a87d-b34b7b1bdf87.jpg
#   inflating: clothing-dataset-small/validation/shirt/c98e8dd6-3fd0-415c-a124-fe6aa1955b74.jpg
#   inflating: clothing-dataset-small/validation/shirt/6791b759-a30d-40bb-84f2-ff32ce939988.jpg
#   inflating: clothing-dataset-small/validation/shirt/a9fe576c-a408-4b3f-80de-d9cb04d36360.jpg
#   inflating: clothing-dataset-small/validation/shirt/66f2df55-c425-40ae-9932-fa929df752d3.jpg
#   inflating: clothing-dataset-small/validation/shirt/118fb0e8-2783-4086-b81a-d2a332fbb4f2.jpg
#   inflating: clothing-dataset-small/validation/shirt/6104b71c-017f-4631-95c9-6ff414091a7d.jpg
#   inflating: clothing-dataset-small/validation/shirt/c560e383-7599-4112-b2d3-482c38aa51e3.jpg
#    creating: clothing-dataset-small/validation/outwear/
#   inflating: clothing-dataset-small/validation/outwear/446df066-edee-4c69-90d7-5013bcc72cf2.jpg
#   inflating: clothing-dataset-small/validation/outwear/fab99089-ea1a-4380-988a-e700bbe73d42.jpg
#   inflating: clothing-dataset-small/validation/outwear/2c1c3c2a-5b22-4133-9509-1877d6a106a0.jpg
#   inflating: clothing-dataset-small/validation/outwear/349cf35c-eaad-49af-b0c9-3c88b8d0afc1.jpg
#   inflating: clothing-dataset-small/validation/outwear/80ea2b05-080f-45f8-afe7-5a09b5071144.jpg
#   inflating: clothing-dataset-small/validation/outwear/5d365198-b2e9-404a-b160-58248c136ef3.jpg
#   inflating: clothing-dataset-small/validation/outwear/161e35df-93d4-4b30-817e-de03c8c1d55a.jpg
#   inflating: clothing-dataset-small/validation/outwear/73580d79-4fce-47f6-a6c3-433b32622774.jpg
#   inflating: clothing-dataset-small/validation/outwear/0ad8629f-2e9f-4591-a661-7489d6d49737.jpg
#   inflating: clothing-dataset-small/validation/outwear/a5c2284f-a7e2-4d4a-aa73-4d5ce5c1443f.jpg
#   inflating: clothing-dataset-small/validation/outwear/febae8c9-1a36-4303-90aa-9fc306278cb2.jpg
#   inflating: clothing-dataset-small/validation/outwear/ba7624a3-d953-4a17-9003-61f350f5785b.jpg
#   inflating: clothing-dataset-small/validation/outwear/a18f1511-770a-4900-b748-691c6021a3b4.jpg
#   inflating: clothing-dataset-small/validation/outwear/2ea87992-6eb5-46a2-9ac6-e4ac727179aa.jpg
#   inflating: clothing-dataset-small/validation/outwear/0c7412e7-81eb-40b7-be64-ce9782103529.jpg
#   inflating: clothing-dataset-small/validation/outwear/6e28fa59-5fe0-418a-ab6a-9b7e1cc9972a.jpg
#   inflating: clothing-dataset-small/validation/outwear/ee4d62e7-6dbc-4131-a394-c199fa564250.jpg
#   inflating: clothing-dataset-small/validation/outwear/42518e91-c969-49f5-ac68-dfe394d7451e.jpg
#   inflating: clothing-dataset-small/validation/outwear/3108045a-9975-4ad8-b5ed-e0a065e5d397.jpg
#   inflating: clothing-dataset-small/validation/outwear/df6097a1-e252-4d2d-bf7a-2d208f932273.jpg
#   inflating: clothing-dataset-small/validation/outwear/311ee106-2f12-4b1d-83fb-b3e597607cca.jpg
#   inflating: clothing-dataset-small/validation/outwear/5f983364-29a4-48f5-8f25-1dd4f220b3ed.jpg
#   inflating: clothing-dataset-small/validation/outwear/f4f59703-4f85-40f5-8ff4-79f2eca93684.jpg
#   inflating: clothing-dataset-small/validation/outwear/2160a577-406a-4812-ada2-2a3cb30c2ba8.jpg

# %% [markdown]
# #### [Optional] Download trained checkpoints for this lecture

# %%
# !gdown https://drive.google.com/drive/folders/1wgRokkvPUoGjsUZqJEhtpJn5e5lDTL4i --folder  # OPTIONAL
# Out:
# Retrieving folder list
# Processing file 1yJT_CluvRxuSiWNnNhPyG5vgon0Re4_t L1_ann_model.ckpt.data-00000-of-00001
# Processing file 1BiOY_1SXdkEHQmb0nVWgos0NnOvjQo1f L1_ann_model.ckpt.index
# Processing file 1fnyJtYPAit6Nsa9cOD7b5G_8rXRnEv0n L1_cnn_model.ckpt.data-00000-of-00001
# Processing file 1pzasWKpoLT-4yUf0ry8r0ykXegRuDzL_ L1_cnn_model.ckpt.index
# Retrieving folder list completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1yJT_CluvRxuSiWNnNhPyG5vgon0Re4_t
# To: /content/Saved Models/L1_ann_model.ckpt.data-00000-of-00001
# 100% 607M/607M [00:26<00:00, 23.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1BiOY_1SXdkEHQmb0nVWgos0NnOvjQo1f
# To: /content/Saved Models/L1_ann_model.ckpt.index
# 100% 1.68k/1.68k [00:00<00:00, 4.90MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1fnyJtYPAit6Nsa9cOD7b5G_8rXRnEv0n
# To: /content/Saved Models/L1_cnn_model.ckpt.data-00000-of-00001
# 100% 201M/201M [00:10<00:00, 19.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1pzasWKpoLT-4yUf0ry8r0ykXegRuDzL_
# To: /content/Saved Models/L1_cnn_model.ckpt.index
# 100% 1.68k/1.68k [00:00<00:00, 5.10MB/s]
# Download completed

# %% [markdown]
# ### 0.2 Import Libraries
#
# a. viz libraries like matplotlib, seaborn etc.
#
# b. DL framework like tf, keras etc.

# %%
# Import common libraries
import os
import glob
import random
import numpy as np
import pandas as pd
import sklearn.metrics as metrics
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Import tensorflow and its modules
import tensorflow as tf
from tensorflow import keras # this allows <keras.> instead of <tf.keras.>
from tensorflow.keras import layers # this allows <layers.> instead of <tf.keras.layers.>
tf.keras.utils.set_random_seed(111) # set random seed

# To supress any warnings during the flow
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Data Visualization
#
# Q. **What to visualize?** Samples, Data Distribution etc.

# %% [markdown]
# > We can see from the data directory that the data is divided into train/valid/test with each containing separate sub-folders for each class!
# > <img src='https://t3638486.p.clickup-attachments.com/t3638486/fc4ad5ff-eb21-4c92-b9da-ff33449da9db/Screenshot%202022-09-06%20at%2007.57.00.png' width=230>
#
# #### **Now let's Plot Samples from each of these classes and Data Distribution across samples!**

# %%
class_dirs = os.listdir("clothing-dataset-small/train") # list all directories inside "train" folder
image_dict = {} # dict to store image array(key) for every class(value)
count_dict = {} # dict to store count of files(key) for every class(value)
# iterate over all class_dirs
for cls in class_dirs:
    # get list of all paths inside the subdirectory
    file_paths = glob.glob(f'clothing-dataset-small/train/{cls}/*')
    # count number of files in each class and add it to count_dict
    count_dict[cls] = len(file_paths)
    # select random item from list of image paths
    image_path = random.choice(file_paths)
    # load image using keras utility function and save it in image_dict
    image_dict[cls] = tf.keras.utils.load_img(image_path)

# %%
## Viz Random Sample from each class

plt.figure(figsize=(15, 12))
# iterate over dictionary items (class label, image array)
for i, (cls,img) in enumerate(image_dict.items()):    
    # create a subplot axis
    ax = plt.subplot(3, 4, i + 1)
    # plot each image
    plt.imshow(img)
    # set "class name" along with "image size" as title 
    plt.title(f'{cls}, {img.size}')
    plt.axis("off")

# %% [markdown]
# - Notice that every Image has **different dimension!**
# - This is expected in a real-world data, but can you guess why this is **not ideal**? Hint: Batching requires all samples to be of the same size!
# - We will see later how we can handle this issue!

# %%
## Let's now Plot the Data Distribution of Training Data across Classes
df_count_train = pd.DataFrame({
    "class": count_dict.keys(),     # keys of count_dict are class labels
    "count": count_dict.values(),   # value of count_dict contain counts of each class
})
print("Count of training samples per class:\n", df_count_train)

# draw a bar plot using pandas in-built plotting function
df_count_train.plot.bar(x='class', y='count', title="Training Data Count per class")
# Out:
# Count of training samples per class:
#          class  count
# 0     outwear    184
# 1       shoes    198
# 2         hat    123
# 3       shirt    290
# 4       dress    241
# 5     t-shirt    795
# 6  longsleeve    455
# 7       skirt    112
# 8      shorts    202
# 9       pants    468

# %% [markdown]
# - Note that the `train/val/test` split already provided, we needn't create it explicitly!
# - Also, we can observe that the data is **imbalanced**. For this lecture, we will work with the given data-distribution, but later on we will see some common techniques to work with imbalanced-data! (Any thoughts?)

# %% [markdown]
# ## 2. Preprocessing
#
# ### Q. **What type of Preprocessing is required here?**
#
# - 2.1 Shape Preprocessing
# - 2.2 Value Preprocessing
# - 2.3 Additional Shape Preprocessing for MLPs

# %% [markdown]
# #### Before that, lets ***mount*** the data directory in Keras using [image_dataset_from_directory](https://www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory) function
#
# Keras provides a utility function (`tf.keras.utils.image_dataset_from_directory`) to directly load data from directory in `tf.data.Dataset` format.

# %%
print('\nLoading Train Data...')
train_data = tf.keras.utils.image_dataset_from_directory(
    "clothing-dataset-small/train", shuffle = True,
)

print('\nLoading Validation Data...')
val_data = tf.keras.utils.image_dataset_from_directory(
    "clothing-dataset-small/validation", shuffle = False,
)

print('\nLoading Test Data...')
test_data = tf.keras.utils.image_dataset_from_directory(
    "clothing-dataset-small/test", shuffle = False,
)
# Out:
# Loading Train Data...
# Found 3068 files belonging to 10 classes.
#
# Loading Validation Data...
# Found 341 files belonging to 10 classes.
#
# Loading Test Data...
# Found 372 files belonging to 10 classes.

# %% [markdown]
# ### 2.1 Shape Preprocessing (Resizing)
#
# - The dataset may contain images of different sizes, but a batch in keras, requires all of them to be of the same size. (Why? , How?)
# - This can be achieved in a multiple of ways, but the most common technique is to resize all images to a fixed size (256, 256)
#
# *Note: We can also provide the resizing parameters while loading data itself.*
#
# ### 2.2 Value Preprocessing (Rescaling)
#
# - We also convert the datatype of input tensor from `uint8` to `float32` and rescale the values to lie between 0 and 1 instead of 0 and 255. (Why?)
# - Without scaling, the high pixel range images will have large influence on loss values and thereby weight updation. (Eg: Black cat vs White cat)
#
# ### 2.3 Shape Preprocessing for MLPs (Flatten)
#
# - Images are 2D* objects (with channel acting as an additional dimension)
# - But Neural Networks requires each sample to be 1D or flat!
# - Now Flattening of this matrix will lead to 3 elements of the vector to have value for that particular pixel as shown below.
#
#
# ><img src='https://drive.google.com/uc?id=1LXJfVbDG23ro2t-7jZ1FC_kzXBT4Xfpw' height=600>
#
# - We will be using **Keras API** `Flatten layer` to convert the image matrix into vector
# - It will change `bs x 256 x 256 x 3` to `bs x 196608`

# %%
height, width = 128, 128 # Optional, not required if we already have resized the data from `image_dataset_from_directory` function.

# Data Processing Stage with resizing and rescaling operations
data_preprocess_with_flatten = keras.Sequential(
    name = "data_preprocess_with_flatten",
    layers = [
        layers.Resizing(height, width),
        layers.Rescaling(1./255),
        layers.Flatten(), # Note: We prefer NOT to add `layers.Flatten()` as part of preprocessing layers (rather as model definition itself)!
    ]
)

# Perform Data Processing on the train, val, test dataset
train_ds = train_data.map(lambda x, y: (data_preprocess_with_flatten(x), y))

# %% [markdown]
# Let's visualize a sample after preprocessing:

# %%
sample = next(iter(train_ds))[0]

print(sample)
# Out:
# tf.Tensor(
# [[0.09552696 0.08768383 0.09944853 ... 0.5103711  0.47507697 0.4084103 ]
#  [0.19276579 0.04910769 0.06562117 ... 0.4493935  0.12782486 0.18272682]
#  [0.63098645 0.5407904  0.6113786  ... 0.93143386 0.939277   0.9353554 ]
#  ...
#  [0.49344397 0.49344397 0.46207142 ... 0.19694066 0.19694066 0.1655681 ]
#  [0.54509807 0.43921572 0.2627451  ... 0.81038606 0.73587626 0.5672488 ]
#  [0.15490197 0.04509804 0.10000001 ... 0.2515235  0.07401124 0.13448918]], shape=(32, 49152), dtype=float32)

# %% [markdown]
# - Its preferred to use flatten layer as part of **model definition**, instead of preprocessing stack, since it's a non-standard preprocessing step, which is not required while working with CNNs.

# %%
# Data Processing Stage with resizing and rescaling operations
data_preprocess = keras.Sequential(
    name="data_preprocess",
    layers=[
        layers.Resizing(height, width), # Shape Preprocessing
        layers.Rescaling(1.0/255), # Value Preprocessing
    ]
)

# Perform Data Processing on the train, val, test dataset
train_ds = train_data.map(lambda x, y: (data_preprocess(x), y))
val_ds = val_data.map(lambda x, y: (data_preprocess(x), y))
test_ds = test_data.map(lambda x, y: (data_preprocess(x), y))

# %% [markdown]
# # **Quiz 1.** A ___ is a preprocessing layer which rescales input values to a new range.<br>
# a) Batch Normalization<br>
# b) Residual Layer<br>
# c) Rescaling<br>
# d) Flatten<br>
# <br>
#
# Ans : c)
# Before feeding into a neural network, we often rescale the values of image pixels to lie between 0 and 1.<br>
# This layer rescales every value of an input (often an image) by multiplying by scale and adding offset.

# %% [markdown]
# ## 3. Training Neural Network
#
# We will start by training a Vanilla NN and then check its performance on test dataset, after this we will switch to CNNs and see how much performance improvement we can get out of it!
#
# - 3.1 Model Architecture of Vanilla NN
# - 3.2 Loss function and Optimizer
# - 3.3 Training and Evaluation with Vanilla NN
# - 3.4 Replacing Vanilla NN with CNNs
# - 3.5 Training and Evaluation with CNNs

# %% [markdown]
# ### 3.1 Model Architecture of Vanilla NN
#
# - Recall the Neural Network structure covered in earilier lecture,
#
# - How Neural Network is made of an Input layer, few Hidden layers and an Output layer with each neuron training on a distinct set of features based on the previous layer’s output.
#
# - These complex connection (weight matrix W) between the neurons helps NN to recognize patterns in the data
# ><img src='https://drive.google.com/uc?id=19BIzu4JiXHNqBgTNXc8PMk_qaYR2nFK5' height=350>

# %%
num_classes = 10
hidden_size_1 = 1024
hidden_size_2 = 256

model = keras.Sequential(
    name="model_ann",
    layers=[
        layers.Flatten(input_shape=(height, width, 3)), # alternatively, input_shape=next(iter(train_ds))[0].shape[1:]
        layers.Dense(units=hidden_size_1, activation='relu'), # hidden layer 1
        layers.Dense(units=hidden_size_2, activation='relu'), # hidden layer 2
        layers.Dense(units=num_classes, activation='softmax'), # output layer
    ]
)

# %% [markdown]
# - So now that we have created the model,
# Lets Visualize **the structure of the model and the number of parameters,** using `.summary()` method.

# %%
model.summary()
# Out:
# Model: "model_ann"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 49152)             0
#
#  dense (Dense)               (None, 1024)              50332672
#
#  dense_1 (Dense)             (None, 256)               262400
#
#  dense_2 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 50,597,642
# Trainable params: 50,597,642
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# - Lets also **plot the model structure** in the form os a graph using `tf.keras.utils.plot_model` command!

# %%
tf.keras.utils.plot_model(model, to_file="model_ann.png", show_shapes=True)

# %% [markdown]
# ### **Q. We have loaded data and defined model architecture, is there something else we need to do, before we start training?**
#
# We need loss functions and optimizers!

# %% [markdown]
# ## **Quiz 2.** Which of the following statements is False with regards to MLP for image data as input ?
# <br>
# a) MLP’s don’t consider spatial relations in an image<br>
# b) MLP’s usually have lesser parameters when compared to CNN’s because they are fully connected.<br>
# c) CNN’s are preferred over MLP’s for image data<br>
# d) None of the above<br>
# <br><br>
# **Ans** : b)<br>
# In MLP’s,  Each node is connected to each node in the previous and the next layer, which causes it to have a very high number of parameters.

# %% [markdown]
# ### 3.2 Loss Function and Optimizer
#
# a. Which loss function to use for multi-class classification?
#
# - **Cross-Entropy loss function might work**
#
# Lets take an example:
# - Supposedly we have a **4 class image classification task of whether the object in the image belong to Dog, Cat, Horse or Cheetah**
#
# - And we train a NN layer

# %% [markdown]
# <center>  <img src='https://drive.google.com/uc?id=16bL7Gxi6SMNhq3DnkH-i3dv2Oc5LV_WF' height=250></center>

# %% [markdown]
# - Notice how **Softmax converts logits (Ouput values) into probabilities.**
# - The purpose of the **Cross-Entropy is to take these output probabilities (P) and measure the distance** from the truth values

# %% [markdown]
# <center>  <img src='https://drive.google.com/uc?id=1yAJ_jb7yCUlnsvQ_eHxc1nKPPcCAdxlj' height=250></center>
# <center>  <img src='https://drive.google.com/uc?
# id=1mCOeR0XcleTmPjuw6xM7-yEYxIvbuGH3' height=120></center>

# %% [markdown]
# ### b. And which Optimizer will work the best ?
# - **Adam optimizer** might work
#
# - **uses both the momentum algorithm to  and Root Mean Square Propagation** (RMSProp) to quickly **reach the global minima**
# - it is computationally efficient
# - little memory required
#
# Lets now compile the model with these loss function and optimizer -
# *Note: We use `sparse_categorical_crossentropy` instead of `categorical_crossentropy`, because the labels are not one-hot encoded!*

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ### 3.3 Training and Evaluation with Vanilla NN
#
# a. Let's train the model for 10 epochs

# %%
epochs = 10
model_fit = model.fit(train_ds, validation_data=val_ds, epochs=epochs)
# Out:
# Epoch 1/10
# 96/96 [==============================] - 9s 66ms/step - loss: 16.9828 - accuracy: 0.2317 - val_loss: 2.9010 - val_accuracy: 0.3636
# Epoch 2/10
# 96/96 [==============================] - 8s 75ms/step - loss: 2.2269 - accuracy: 0.3765 - val_loss: 2.0419 - val_accuracy: 0.3695
# Epoch 3/10
# 96/96 [==============================] - 7s 64ms/step - loss: 2.0304 - accuracy: 0.3950 - val_loss: 1.9385 - val_accuracy: 0.3900
# Epoch 4/10
# 96/96 [==============================] - 7s 65ms/step - loss: 1.9046 - accuracy: 0.4263 - val_loss: 1.7731 - val_accuracy: 0.4399
# Epoch 5/10
# 96/96 [==============================] - 7s 65ms/step - loss: 1.5782 - accuracy: 0.4990 - val_loss: 1.8575 - val_accuracy: 0.4370
# Epoch 6/10
# 96/96 [==============================] - 7s 65ms/step - loss: 1.5179 - accuracy: 0.5199 - val_loss: 2.0026 - val_accuracy: 0.3959
# Epoch 7/10
# 96/96 [==============================] - 7s 64ms/step - loss: 1.6271 - accuracy: 0.4847 - val_loss: 1.9305 - val_accuracy: 0.4135
# Epoch 8/10
# 96/96 [==============================] - 7s 64ms/step - loss: 1.4813 - accuracy: 0.5205 - val_loss: 1.6501 - val_accuracy: 0.4633
# Epoch 9/10
# 96/96 [==============================] - 7s 64ms/step - loss: 1.4239 - accuracy: 0.5323 - val_loss: 2.0007 - val_accuracy: 0.3284
# Epoch 10/10
# 96/96 [==============================] - 7s 64ms/step - loss: 1.4485 - accuracy: 0.5284 - val_loss: 1.6289 - val_accuracy: 0.4457

# %% [markdown]
# ### b. Did the training go well ?
# - Lets plot the training and validation loss and accuracy curves

# %%
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(15,5))
ax = axes.ravel()

#accuracy graph
ax[0].plot(range(0,model_fit.params['epochs']), [acc * 100 for acc in model_fit.history['accuracy']], label='Train', color='b')
ax[0].plot(range(0,model_fit.params['epochs']), [acc * 100 for acc in model_fit.history['val_accuracy']], label='Val', color='r')
ax[0].set_title('Accuracy vs. epoch', fontsize=15)
ax[0].set_ylabel('Accuracy', fontsize=15)
ax[0].set_xlabel('epoch', fontsize=15)
ax[0].legend()

#loss graph
ax[1].plot(range(0,model_fit.params['epochs']), model_fit.history['loss'], label='Train', color='b')
ax[1].plot(range(0,model_fit.params['epochs']), model_fit.history['val_loss'], label='Val', color='r')
ax[1].set_title('Loss vs. epoch', fontsize=15)
ax[1].set_ylabel('Loss', fontsize=15)
ax[1].set_xlabel('epoch', fontsize=15)
ax[1].legend()

#display the graph
plt.show()

# %% [markdown]
# b. Let's evaluate it on Test Dataset
#
# We will calculate accuracy and generate confustion-matrix on the Test Dataset!

# %%
# load model from pretrained checkpoints (optional)
model.load_weights("/content/Saved Models/L1_ann_model.ckpt")

# run model prediction and obtain probabilities
y_pred = model.predict(test_ds)

# get list of predicted classes by taking argmax of the probabilities(y_pred)
predicted_categories = tf.argmax(y_pred, axis=1)

# get list of class names
class_names = test_data.class_names

# create list of all "y"s labels, by iterating over test dataset
true_categories = tf.concat([y for x, y in test_ds], axis=0)

# calculate accuracy
test_acc = metrics.accuracy_score(true_categories, predicted_categories) * 100
print(f'\nTest Accuracy: {test_acc:.2f}%\n')
# Out:
# Test Accuracy: 36.56%

# %%
def ConfusionMatrix(model, ds, label_list):
# Note: This logic doesn't work with shuffled datasets
    # run model prediction and obtain probabilities
    y_pred = model.predict(ds)
    # get list of predicted classes by taking argmax of the probabilities(y_pred)
    predicted_categories = tf.argmax(y_pred, axis=1)
    # create list of all "y"s labels, by iterating over test dataset
    true_categories = tf.concat([y for x, y in ds], axis=0)
    # generate confusion matrix and plot it
    cm = metrics.confusion_matrix(true_categories,predicted_categories) # last batch 
    sns.heatmap(cm, annot=True, xticklabels=label_list, yticklabels=label_list, cmap="YlGnBu", fmt='g')
    plt.show()

ConfusionMatrix(model, test_ds, test_data.class_names)

# %% [markdown]
# c. Let's also plot few samples from test set along with their predicted softmax probabilities.
#
# - We plot the image and the predicted array (as bar plot) side-by-side.
# - The predicted array is the class probabilities (output from softmax layer) corresponding to 10 classes.
# - If the tallest bar (argmax) in the bar-plot is the true label, we color it blue else it's colored red.
# - Height of the bar plot indicates what's the probability of it predicting that label.

# %%
# function to plot image given image, its true label and class probabilities (pred_array)
def plot_image(pred_array, true_label, img):
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(pred_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(pred_array),
                                class_names[true_label]),
                                color=color)

# function to plot barplot of class probabilities (pred_array)
def plot_value_array(pred_array, true_label):
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), pred_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(pred_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
true_categories = tf.concat([y for x, y in test_ds], axis=0)
images = tf.concat([x for x, y in test_ds], axis=0)
y_pred = model.predict(test_ds)
class_names = test_data.class_names

# Randomly sample 15 test images and plot it with their predicted labels, and the true labels.
indices = random.sample(range(len(images)), 15)
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i,index in enumerate(indices):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(y_pred[index], true_categories[index], images[index])
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(y_pred[index], true_categories[index])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.4 Replacing Vanilla NN with CNNs
#
# - We saw hammering image data doesn't yield good results. Let's find the right set of tool that would do its job, aka CNNs.
# - Let's replace the first dense layer with a simple convolution block, keeping everything else same.
# - A typical Convolution Block comprises of a `Conv2D` layer followed by a `MaxPooling2D` layer!
#
# *(Don't worry if you don't understand what all of this means, it will be explained in detail in later sections)*
#
# a. Model Architecture

# %%
num_classes = 10
hidden_size = 256

model = keras.Sequential(
    name="model_cnn",
    layers=[
        layers.Conv2D(filters=16, kernel_size=3, strides=1, padding="same", activation='relu', input_shape=(height, width, 3)),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(units=hidden_size, activation='relu'),
        layers.Dense(units=num_classes, activation='softmax')
    ]
)

# %%
tf.keras.utils.plot_model(model, to_file="model_cnn.png", show_shapes=True)

# %%
model.summary()
# Out:
# Model: "model_cnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 16)       0
#  )
#
#  flatten_2 (Flatten)         (None, 65536)             0
#
#  dense_3 (Dense)             (None, 256)               16777472
#
#  dense_4 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 16,780,490
# Trainable params: 16,780,490
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# b. Compile the model with **cross-entropy** loss and **adam** optimizer:

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ### 3.5 Training and Evaluation with CNNs
#
# a. Training for same 10 epochs

# %%
epochs = 10
model_fit = model.fit(train_ds, validation_data=val_ds, epochs=epochs)
# Out:
# Epoch 1/10
# 96/96 [==============================] - 15s 65ms/step - loss: 4.6031 - accuracy: 0.3057 - val_loss: 2.0120 - val_accuracy: 0.3666
# Epoch 2/10
# 96/96 [==============================] - 7s 64ms/step - loss: 1.6114 - accuracy: 0.4837 - val_loss: 1.6362 - val_accuracy: 0.4751
# Epoch 3/10
# 96/96 [==============================] - 6s 63ms/step - loss: 1.3366 - accuracy: 0.5812 - val_loss: 1.5580 - val_accuracy: 0.5161
# Epoch 4/10
# 96/96 [==============================] - 6s 63ms/step - loss: 1.0319 - accuracy: 0.6767 - val_loss: 1.4881 - val_accuracy: 0.5220
# Epoch 5/10
# 96/96 [==============================] - 7s 64ms/step - loss: 0.8030 - accuracy: 0.7585 - val_loss: 1.4169 - val_accuracy: 0.5425
# Epoch 6/10
# 96/96 [==============================] - 6s 63ms/step - loss: 0.5880 - accuracy: 0.8302 - val_loss: 1.4555 - val_accuracy: 0.5484
# Epoch 7/10
# 96/96 [==============================] - 6s 63ms/step - loss: 0.4126 - accuracy: 0.9009 - val_loss: 1.3997 - val_accuracy: 0.5572
# Epoch 8/10
# 96/96 [==============================] - 6s 64ms/step - loss: 0.3046 - accuracy: 0.9316 - val_loss: 1.4658 - val_accuracy: 0.5718
# Epoch 9/10
# 96/96 [==============================] - 6s 63ms/step - loss: 0.2206 - accuracy: 0.9531 - val_loss: 1.4693 - val_accuracy: 0.5806
# Epoch 10/10
# 96/96 [==============================] - 6s 63ms/step - loss: 0.1502 - accuracy: 0.9743 - val_loss: 1.7410 - val_accuracy: 0.5132

# %% [markdown]
# b. How well the training go?
#
# Accuracy and Loss Plots on train/val datasets

# %%
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(15, 5))
ax = axes.ravel()

#accuracy graph
ax[0].plot(range(0,model_fit.params['epochs']), [acc * 100 for acc in model_fit.history['accuracy']], label='Train', color='b')
ax[0].plot(range(0,model_fit.params['epochs']), [acc * 100 for acc in model_fit.history['val_accuracy']], label='Val', color='r')
ax[0].set_title('Accuracy vs. epoch', fontsize=15)
ax[0].set_ylabel('Accuracy', fontsize=15)
ax[0].set_xlabel('epoch', fontsize=15)
ax[0].legend()

#loss graph
ax[1].plot(range(0,model_fit.params['epochs']), model_fit.history['loss'], label='Train', color='b')
ax[1].plot(range(0,model_fit.params['epochs']), model_fit.history['val_loss'], label='Val', color='r')
ax[1].set_title('Loss vs. epoch', fontsize=15)
ax[1].set_ylabel('Loss', fontsize=15)
ax[1].set_xlabel('epoch', fontsize=15)
ax[1].legend()

#display the graph
plt.show()

# %% [markdown]
# c. Evaluation on Test Dataset
#
# Print Classification Report, Confusion Matrix and plot a few samples (with their probabilities)!

# %%
# load model from pretrained checkpoints (optional)
model.load_weights("/content/Saved Models/L1_cnn_model.ckpt")

true_categories = tf.concat([y for x, y in test_ds], axis=0)
images = tf.concat([x for x, y in test_ds], axis=0)
y_pred = model.predict(test_ds)
class_names = test_data.class_names
predicted_categories = tf.argmax(y_pred, axis=1)

test_acc = metrics.accuracy_score(true_categories, predicted_categories) * 100
print(f'\nTest Accuracy: {test_acc:.2f}%\n')
# Out:
# Test Accuracy: 50.27%

# %%
ConfusionMatrix(model, test_ds, test_data.class_names)

# %%
true_categories = tf.concat([y for x, y in test_ds], axis=0)
images = tf.concat([x for x, y in test_ds], axis=0)
y_pred = model.predict(test_ds)
class_names = test_data.class_names

# Randomly sample 15 test images and plot it with their predicted labels, and the true labels.
indices = random.sample(range(len(images)), 15)
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i,index in enumerate(indices):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(y_pred[index], true_categories[index], images[index])
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(y_pred[index], true_categories[index])
plt.tight_layout()
plt.show()

# %% [markdown]
# **We see a BIG jump in accuracy numbers** both for validation and test sets. Therefore, where we have screw aka image data, using a specialist tool like screw-driver (CNNs) instead of a hammer (vanilla NN) proves to be more effective!
#
# - In the next section we will investigate why Vanilla NN performed poorly on image data, what special properties CNN possess and how CNN architecture is different than that of Vanilla NN.

# %% [markdown]
# # PART 2: Understanding the Screwdriver (CNN)
#
# Now that we tried to hammer(ANN) a Screw (Image data) i.e. fit our data to a ANN, we observed :
# - ANN gave an test accuracy of 27% on the data
# - By adding a single Covolutional and MaxPool layer to the existing network,
# - we achieved 51% (nearly double) test accuracy
#
# >This raises 2 IMPORTANT questions:
# 1.   #### **Why did the *Hammer* (MLP) FAIL in this *scenario* (Image Data)?**
# 2.   #### **What SPECIAL Features helped Screwdriver (CNN) to succeed?**

# %% [markdown]
# #### Let's address them one by one:
#
# ## 1. **What are the problems with MLP for Image Data?**

# %% [markdown]
# ### a. MLP will **react differently to an image and its shifted version**
# - Since **MLP flattens the image, it is not position invariant**
# - In PART 1, we fitted our image to ANN
# - Converted the image into a single feature vector,
# - hence **not considering** the neighbouring pixels, and
# - most importantly the Image channels (R-G-B)
#
# Lets take an example
#
# - Supposedly we have **two images of the same dog but at two different position**
# - One on the Upper left while one on the middle right
#
# ><img src='https://drive.google.com/uc?id=1s0OD8Zdh0J7yFsvqvGeFEir5dzNCMjf_' height=200>                  <img src='https://drive.google.com/uc?id=1m_zIzbJGuXXTacENxTMeVb1dHvrpzb-E' height=200>
#
# - Now since MLP will **flatten the matrix, the neurons which might be more active for the first image will be dormant for the second one**
# - Making **MLP think these two images having completely different objects**

# %% [markdown]
# ### b. **MLP doesnot consider Spatial relations**
#
# - Spatial Information (like if a Person is standing at the right side of the Car or The red car is on the left side of the blue bike) gets lost when image is flattened
#
# - Flattening also loses the internal representation of the 2D image.
#
# ### c. **Includes too many Parameters**
# - Since **MLP is a fully connected model, it requires a neuron for every input pixel of the image**
#
# - Now Lets take an example with an image of size (1280 x 720) .
#   - For an image with **dimension as such the vector for the input layer becomes (921600 x 1)**. if a **Dense layer of 128 is used  then the number of parameters  equals = 921600*128.**
#   - This makes **MLP infeasible  for large image** and it may **cause overfitting.**

# %% [markdown]
# #### Do we even require global connectivity ?
# - The global connectivity  caused due to densely connected neurons leads to  more reduntant parameters which makes the MLP overfit
#
# ### With all the above discussion we need:
# - to make the system translation (position) invariant
# - to leverage the spatial correlation between the pixels
# - focus only on the local connectivity

# %% [markdown]
# ## **2. What should be the SPECIAL Features of CNN?**
#
# From the above discussion and taking inspiration from our visual cortex system, there are 3 essential properties of image data:
#
# **1. LOCALITY** : Correlation between neighbouring pixels in a Image
# **2. STATIONARITY** : Similar Patterns appearing multiple times in a Image
# **3. COMPOSITIONALITY** : Extracting higher level features by pooling lower level features
#
# ### **Can we add these properties to Vanilla NN? If yes, How?** [Optional for instructor to explain]
#
# - **Sparse Connections for Locality** - Since we already know that in the case of images, local features are highly correlated as opposed to far-away features, lets get rid of the far-away connections and make it sparse as shown below!
# This restricts the Receptive Field (RF) of the neurons from 5RF to 3RF for the next hidden layer (3RF)!
# ><img src='https://drive.google.com/uc?id=1z9RR-NHbJXnb2Vuxc_I0v-4XwX_vDnYB' height=320>
# <img src='https://drive.google.com/uc?id=10Frr3nGMeqvEVe3kiyoKq7pXwH2nLkql' height=380>
#
#     *Note that the Receptive field of the hidden layers wrt to the initial layers increases as we go deeper!*
#
# - **Parameter Sharing for Stationarity** - Also, since there are repeating patterns in an image, it could be helpful to share some connections as shown below.
# ><img src='https://drive.google.com/uc?id=1vCiCIkkQQmXNYXl4gXvkAFXLIdfl2owv' height=350>
# <img src='https://drive.google.com/uc?id=1h6O-lxz-k98Q5tSgMJuxBtySNoedMnaY' height=380>
#     Instead of learning 3 separate sets of [3x1] matrix, we can get away with learning just one [3x1] matrix!
#
# - Both these operations combined, greatly reduces the number of parameters in the architecture while preserving the "inductive bias" in the input signal. ***Note that, unlike in MLP; here, the number of parameters is now independent of number of neurons in the previous layer!***
#
# ####In 2D, these two operations lead to a set of learnable parameters of size **k*k** (called Filters or Kernels) and the computations performed by these kernels are called **CONVOLUTION**!

# %% [markdown]
# ##Components in CNN:
#
# ### Q. What is a **Convolution Operation**?
#
# We have already seen that in the case of 1D vector, convolution is nothing but element-wise dot-product with a kernel of fixed size. After summing, we get a single output point corresponding to the operation. Next, we slide and "convolve" the same kernel across the length of entire vector to obtain the final result.
#
# #### Now we will see how this kernel will work in the case of 2D matrix -

# %% [markdown]
# ### What is a 2D Kernel ?
#
# ><img src='https://drive.google.com/uc?id=1mQ95EJrwQ_5LoGGiAU-9pT29V0hiM5fg' height=350> <img src='https://drive.google.com/uc?id=1eDZVHsrY63jdaOSu1nu_lasKANLXL6j8' height=350>
#
# - A kernel can be visualized as a small matrix that slides across, from left-to-right and top-to-bottom, of a larger image.
# - At each pixel in the input image, the neighborhood of the image
# is convolved with the kernel and the output stored.
# - Inshort, a kernel find relations within the neighbouring pixels in its area iteratively and once the finishes sliding over the image, it is able to correlate certain features in a image
# - For example :
#     - We have an image of a car on a road, the kernel when sliding over the image wil be able to identify the edges (shape) of a car, by correlating the pixels between the car and the road.
# ### **Let's see how can we make Computer to detect vertical edges ?**
#
# ><img src='https://drive.google.com/uc?id=1OoNlFfmCNyky1bXHDmc4KpWoJiPCqJDY' height=250>
#
#
# #### By using APPROPRIATE kernels/filters.

# %% [markdown]
# Let's take an example of 1-channel Input Image and a given 3x3 kernel -
# - Here **10 denotes a bright pixel while 0 denotes a dark one**
# - We can clearly **see the vertical line that separates the two**
#
# - Let's now convolve the kernel on the Image to see what we get as output:
#
# ><img src='https://drive.google.com/uc?id=1kh3QKOs5guhFJm5YIFYckOcDl3Otdxbp' height=400>
# ><img src='https://drive.google.com/uc?id=1pQZuoABSsdrquQleFht54c9zLLPAFPuQ' height=400>

# %% [markdown]
# - See how the **right element of the kernel captures brighter pixels** and the **darkest pixels can be captured by the left elements**
#
# - Now we will convolve or traverse the kernel to each of the selected region **(highlighted in green in image below)**
#
# - **multiply each element to the kernel/filter element** and then **sum them all**
#
# - the **value comes out to be 0** which forms the first element of the output matrix.
#
# - Now the **kernel then shifts one column to the right** and again computes the operation. The amount of shifting is also called `stride`. In this case the stride is 1 both in horizontal and vertical direction. If the kernel shifted by two column towards right and only one towards botton, stride would have been (2,1).
#
# - Notice **after some computing**, the **output matrix was able to detect the vertical line** (highlighted in blue) which separated the bright and dark object.
#
# - Also this **shifting of kernel/filter help make the image translation invariant** as **no matter where the vertical line is**, the **output matrix will have the same pixel values for the vertical lines.**

# %% [markdown]
# ####Q. **What kind of filter do you think we can use for detecting horizontal edges?**
# ><img src='https://drive.google.com/uc?id=1UjhrHs9KV4s6A_yiSn2DtlXM2wQHlwQz' height=220>

# %% [markdown]
# ####Q. **How can we apply both horizontal and vertical edge detector on the same image matrix?**
#
# - By stacking Output from both the filters applied separately to the image!
# - Notice that there is now a third Dimension to the Output Image, which is equal to the number of filters.
#
# > <img src='https://drive.google.com/uc?id=1CCz2uqnXazLy-ONlNpXlE5RylGMe5Lar' height=300>

# %% [markdown]
# ####Q. **What happens when we have a RGB Image as Input?**
#
# - If the Input Image has more than 1 channel, each Kernel will have a depth associated with it (which is equal to the number of channels in Input Image) and the Convolution will be performed over the entire **VOLUME** of the input image as show here:
# > <img src='https://drive.google.com/uc?id=1qF9sKmxlC3xNq278qog9LxTf8NbSz34w' height=270>
#
#
# - In the case of 2 filters, we get an output dimension of 4x4x2.
# > <img src='https://drive.google.com/uc?id=1_SrrE9GLYrb1660H0MSDar8eSSmLF4vh' height=300>

# %% [markdown]
# #### Q. **Are these two Kernels enough to know?**
#
# - Until now, we have seen just two kernels, Horizontal and Vertical; but there can be arbitrarily many such kernels which extracts useful features from image. Which all kernels to keep depends on the type of problem and datasets, we are dealing with.
# - But in the case of Deep Learning, we don't handcraft feature extractors, rather we let the model learn them using **Gradient Descent**!
# - Similarly here too, we will just specify the dimension and number of kernels we want, and let the model learn the values in each of those kernel.
# - These learnable kernels essentially form a **Conv Layer**.

# %% [markdown]
# #### Q. **If these Kernels are learnable, how many number of parameters are there in a Convolution Layer?**
#
# - Number of parameters in a Conv Layer depends on the filter size, no. of filters, and the input image dimension.
#
# - Thus for every filter, we have `(m * n * d)+1` parameters, where m,n stands for width and height of the filter and d is the number of channels in previous layer. Additional 1 bias term is also added.
# - In total for `k` filters, we have `((m *n *d)+1)*k` parameters.

# %% [markdown]
# #### Q. **Calculate the number of parameters in the Conv Layer of the CNN architecture (Part 1)?**
#
# - In the Conv Layer, total no. of params is just ((3 \* 3 \* 3) + 1) * 48 = 1334

# %% [markdown]
# ###Q. Did you notice that we have always used **Odd** Kernel Size of 3x3 instead of **Even** like 2x2 or 4x4? Why?
#
# - In Odd sized kernel, all the previous layer pixels would be Symmetric around the Output pixel
# - Without this Symmetric, we will account for distortion across all the layers which happen when we use Even sized kernel.
#
# Let's understand this with an example:
# - On the left, we have a 3×3 matrix. The center of the matrix is located at
# x = 1, y = 1 where the top-left corner of the matrix is used as the origin and our coordinates are zero-indexed.
# - But on the right, we have a 2×2 matrix. The center of this matrix would be located at x = 0.5, y = 0.5.
# - But as we know, there is no such thing as pixel location (0.5, 0.5) – our pixel coordinates must be integers! This reasoning is exactly why we use odd kernel sizes i.e. to always ensure there is a valid (x, y)-coordinate at the center of the kernel.
# ><img src='https://drive.google.com/uc?id=1vCPa45XsvDiCKgHJSqRJbK10ZUsJugd6' height=300>
#
# Thus, we use an odd kernel size to ensure there is a valid integer (x, y) coordinate at the center of the image.

# %% [markdown]
# ####One more thing, Did you notice that the output matrix has a shape of 4x4 instead of 6x6?
#
# ###Q. **Why did the shape of the output matrix reduce ?**
# - The filter/kernel was shifting and computing over 3x3 region
# - So the area covered by the kernel/filter: `o = n-f+1`
#   - where o is the output dimension, n is the input dimension and f is the kernel dimension
# - Hence the Output dimension of the matrix became: `6-3+1 = 4`

# %% [markdown]
# #### Q. **How can we solve the issues of shrinking output and less use of corner pixels?**
#
# - By **Padding or adding pixels around the border** of the image before applying convolution.
#
# #### Let's understand it in more detail:

# %% [markdown]
# ### Q. Why **Padding** is required in convolution?
# - By applying the convolution operation without padding, we not only get output which is smaller in shape but more importantly, we loose the information at the corner of the images.
# - The following diagram show that without padding the corner pixels are covered only 1 times, edge pixel are covered 2 times and all the remaining pixels are covered 3 times.
# ><img src='https://drive.google.com/uc?id=1mQ95EJrwQ_5LoGGiAU-9pT29V0hiM5fg' height=350> <img src='https://drive.google.com/uc?id=1Fok3EPH7EKJ-e2lP5T45phfh_72aC8mK' height=350>
#
# By padding we ensure that all the pixels are covered equally as shown in the figure above. [Image]
# - The output shape, `o` is now given by;
#     `o = n+2p-f+1`, where p is the padding width applied at all sides.
#
# Alternative Explanation:
# - If we attempted to apply convolution at the pixel located at (0,0), then our 3×3 kernel would **“hang off”** off the edge of the image.
# - Notice how there are no input image pixel values for
# the first row and first column of the kernel. Because of this, we always either start convolution at the first valid position
# <!-- <img src='https://drive.google.com/uc?id=10wB6bAxpVCod38m_AUL61idMTp5AuW6c' height=350> -->
#
#
# Thus padding is helpful because of following reasons:
#   1. It help us in preserving the information at the corner of the image. Without padding, the information at the corner of the image will be lost.
#   2. Without padding, the height $n_H$ and width $n_W$ decreases after the convolution operation. By using the padding, we can apply the convolution operation without decreasing the height and width of the image.

# %% [markdown]
# ####Q. **Is there another way to reduce the dimension of layer outputs and possibly control it?**
#
# Yes. **Through Stride Size.**
#
# - Strides define by how much the kernel will **slide** on the Input Image while Convolving.
# - Keeping a higher value of stride leads to quicker decrease in dimension of the Image. The image shown below shows stride of 2.
#
# > <img src='https://drive.google.com/uc?id=11wVCDd-8MMhjzsJt0n_KCxyT8OjA_YYQ' height=300>
#
# - The new output shape, `o` is now equal to; `o = (n+2p-f)/s + 1`.
#
# ###Thus the formula for output shape is given by:
# > <img src='https://drive.google.com/uc?id=1uHepupWMJIHxTQ9PEIJ6TLu0Mc7VItvG' height=70>

# %% [markdown]
# #### Q. **What is the effect of using a larger stride?**
#
#   - Lesser Memory needed for output
#   - The Output Spatial dimensions are smaller which when simplify the model
#   - It avoids Overfitting by not overlapping redundant pixels together

# %% [markdown]
# ### **Lets now revisit the code where we used Convolution layer and understand its arguments** -

# %%
layers.Conv2D(filters=48, kernel_size=3, strides=1, padding="same", activation='relu', input_shape=(128, 128, 3))

# %% [markdown]
# Let's go over the arguments, one by one:
# 1. `filters`: It denotes number of unique filters that this convolutional layers will learn. This also determines the number of output filters in the convolution.
# 2. `kernel_size`: This specifies the size of the kernel/filter which will convolve over the previous layer. It can be either an integer value or a 2-tuple denoting the width and height of the 2D convolution window, like `(3,3)`, `(5,5)` etc.
# 3. `strides`: Like kernel_size, we can specify the distance by which the kernel would slide over the input image in terms of integers or a tuple of 2 integers. Default is `(1,1)`.
# 4. `padding`: As discussed, padding can be of two types, `same` or `valid`. Same keeps the output spatial dimensions same as the input, whereas valid means no padding, and allows the size to shrink as a result of convolution. Defaults to `valid`.
# 5. `activation`: Added for convenience, this argument specifies what type of non-linearity should be applied *after convolution*! Defaults to `None`.
# 6. `input_shape`: Need to be provided only if it is the first layer in the network! The input shape helps to determine the number of parameters in the layer and the output shape!

# %% [markdown]
# ## **Quiz 3:** Which of the following are True about Padding in CNN?<br><bR>
# a) We should use valid padding if we know that information at edges is not that much useful.<br>
# b) We compromise to lose some edge information of the image in the case of ‘same’ padding.<br>
# c) There is no reduction in dimension when we use ‘same’ padding.<br>
# d) In ’valid’ padding, we drop the part of the image where the filter does not fit.
# <br><br><br>Ans : a), c), d)
# <Br>
# **Solution :** <br>
# - We use valid padding if we know that information at edges is not that much useful.(The output size of the convolutional layer shrinks depending on the input size & kernel size.)
# - In zero padding, we pad zeros around the border of the image to save most of the information, whereas in valid padding, we lose out on the information which doesn’t fit in filters.
# - There is no reduction in dimension when we use zero padding.(This is True)
# - In valid padding, we drop the part of the image where the filter does not fit. (This is True)
# <br><br>
# Hence, A, C and D are correct.

# %% [markdown]
# ## **Pooling**
#    Apart from Conv2D, we also used another specific module called `MaxPooling2D` in our model, which had no learnable parameters.
#
# #### Let's try to understand what is Pooling and what is the significance of a Pooling Module.
#
#    The pooling layer helps in reducing the height and width of the image. Thus, it helps in reducing the number of parameters and also make invariant to the position in the input. In other words, it induces "compositionality" in our model architecture.
#
#    There are two kinds of pooling :
#
#    1. Max pooling : The filter of size $(f,f)$ is slided over the input with a stride and we take the maximum in that region. It is used in between the Conv Layers.
#
#    2. Average pooling : The filter of size $(f,f)$ is slided over the input with a sride and we take the average in that region. This type of pooling is generally used just before the Fully connected layers for feature extraction!
#
#
# ><img src='https://drive.google.com/uc?id=1inJMPLbFxf5MyLRIOYHIjhIqEw_r31Ho' height=270> <img src='https://drive.google.com/uc?id=1TFIRlEtBxAjXqg-tFzj9hgXoWuEQb2Lc' height=270>
#
#
#   The above figure illustrates the max pooling and average pooling using a filter (2,2) dimension and having a stride of 2.

# %% [markdown]
# #### Q. **Does pooling layers add any learnable weights to the network?**
# - **No, since notice that no kernel/filter matrix is considered.**
# - Hence no parameters are needed while computing pooling

# %% [markdown]
# #### Q. **What is the Output shape after pooling layer?**
# The output shape is given by: $o = floor[(\frac{n-f}{s}) + 1]$, where n is the input size, f is the pooling filter size and s is the stride size.

# %% [markdown]
# ### Let's now see How Pooling works in Keras?

# %%
layers.MaxPooling2D()

# %%
layers.AveragePooling2D(),
# Out:
# (<keras.layers.pooling.AveragePooling2D at 0x7f13fdaaca50>,)

# %% [markdown]
# Both these Pooling layers have 2 important arguments:
#
# 1. `pool_size`: This is the size of the window on which pooling will be applied. By default this size is 2. Can be an integer or a tuple of 2 integers. It can also be thought of as a non-learnable filter which either calculates max over the region or average out the values.
# 2. `strides`: This is same as the one in `Conv2D` layer. Default is None, which means that the stride size is same as the pool size.

# %% [markdown]
# ### Why we do flattening in CNN ?
# - This step is pretty simple, lets have a short discussion
#
# - After finishing the previous two steps, we're supposed to have a pooled feature map by now.
# - As the name of this step implies, we are literally going to flatten our pooled feature map into a column like in the image below.
#
# > <img src='https://drive.google.com/uc?id=1aIWkfcjMaEnj7hOYPSjlBoS4Pb0000Qf' height=260 width=620>

# %% [markdown]
# The reason we do this is that we're going to need to insert this data into an artificial neural network later on.
#
# ><img src='https://drive.google.com/uc?id=17D_z-xzRSCJZK5OMsaVEJycMWnrTk2dV' height=270>

# %% [markdown]
# As you see in the image above, we have multiple pooled feature maps from the previous step.
#
# What happens after the flattening step is that you end up with a long vector of input data that you then pass through the artificial neural network to have it processed further.

# %% [markdown]
# ## **Quiz 4.** An input image has a matrix of size 12 X 12. A filter of size 3 X 3 with a Stride of 1 and no padding is applied on this image input. <br>Determine the size of the output matrix.
#
# a) 10 X 10<br>
# b) 12 x 12<br>
# c) 9 x 9<br>
# d) 10 x 12<br>
# <br>
#
# **Solution :** Use the formula : C = ((n-f+2p)/s)+1<br>
# Here, n = 12<br>
# F = 3<br>
# P = 0<br>
# S = 1<br>
# C = ((12-3+0)/1) + 1<br>
#
# Output size = 10 x 10

# %% [markdown]
# ## Summary :
#
# To sum up, here is what we have after we're done with each of the steps in our first CNN that we have covered up until now:
#
# - Input image (starting point)
# - Convolutional layer (convolution operation)
# - Activation function
# - Pooling layer (pooling)
# - Input layer for the artificial neural network (flattening)
# - Dense layer
# - Loss function
#
# In the next class, we will discuss more about the CNN components  and how to deal with overfitting in CNN.
